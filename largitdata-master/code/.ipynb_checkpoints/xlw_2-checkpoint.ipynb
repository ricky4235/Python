# %%
import xlwings as xw
import pandas as pd
import numpy as np

wb = xw.Book(r'C:\Users\11004076\Documents\Python Scripts\4_Automation\20200324-進銷存-SF4_Vietnam_Silicom.xlsx')
sht = wb.sheets['raw']
raw = sht.range('A1').expand('table')
df = pd.DataFrame(raw.value)
df.columns = df.loc[0] #將欄位名稱和第0列一樣
df.drop(0, axis = 0, inplace=True)  #再將多餘的第0列丟掉
df.head()
# Out:
# 0  進銷存 2nd Item Number   Qty LargeCat    MediumCat Sls CD4 Desc#  \
# 1  進貨量     3.10101e+10  6200    Mouse  Wired Mouse        DX-110
# 2  進貨量     3.10101e+10   500    Mouse  Wired Mouse        DX-110
# 3  進貨量     3.10101e+10  1000    Mouse  Wired Mouse        DX-110
# 4  進貨量     3.10101e+10   300    Mouse  Wired Mouse        DX-110
# 5  進貨量     3.10101e+10   500    Mouse  Wired Mouse        DX-110
#
# 0           Product Desc#  Year Month
# 1  RS,DX-110,USB,BLACK,G5  2019     2
# 2  RS,DX-110,USB,WHITE,G5  2019     2
# 3   RS,DX-110,USB,BLUE,G5  2019     2
# 4    RS,DX-110,USB,RED,G5  2019     2
# 5  RS,DX-110,USB,GREEN,G5  2019     2

# %%
df
# Out:
# 0     進銷存 2nd Item Number   Qty LargeCat    MediumCat         Sls CD4 Desc#  \
# 1     進貨量     3.10101e+10  6200    Mouse  Wired Mouse                DX-110
# 2     進貨量     3.10101e+10   500    Mouse  Wired Mouse                DX-110
# 3     進貨量     3.10101e+10  1000    Mouse  Wired Mouse                DX-110
# 4     進貨量     3.10101e+10   300    Mouse  Wired Mouse                DX-110
# 5     進貨量     3.10101e+10   500    Mouse  Wired Mouse                DX-110
# ...   ...             ...   ...      ...          ...                   ...
# 1229  銷貨量     3.17102e+10    80  Headset      Headset               HS-200C
# 1230  銷貨量       3.173e+10   668  Speaker  USB Speaker      USB SoundBar 100
# 1231  銷貨量       3.173e+10   246  Speaker  USB Speaker              SP-HF180
# 1232  銷貨量       3.173e+10    36  Speaker  USB Speaker              SP-HF180
# 1233  銷貨量       3.109e+10    11    Other        Other  Media Pointer 100 V3
#
# 0                      Product Desc#  Year Month
# 1             RS,DX-110,USB,BLACK,G5  2019     2
# 2             RS,DX-110,USB,WHITE,G5  2019     2
# 3              RS,DX-110,USB,BLUE,G5  2019     2
# 4               RS,DX-110,USB,RED,G5  2019     2
# 5             RS,DX-110,USB,GREEN,G5  2019     2
# ...                              ...   ...   ...
# 1229               RS,HS-200C,SINGLE  2020     3
# 1230  RS2,USB SoundBar 100,BLK,GP-1!  2020     3
# 1231  RS2,SP-HF180,WOOD,USB,GP-1900!  2020     3
# 1232  RS2,SP-HF180,BLK,USB,GP-190006  2020     3
# 1233   RS,MEDIA POINTER 100,RUN CARD  2020     3
#
# [1233 rows x 9 columns]

# %%
df[  (df['Year'] == 2020) & (df['進銷存'] == '進貨量')  ]
# Out:
# 0    進銷存 2nd Item Number   Qty      LargeCat       MediumCat  \
# 200  進貨量     3.10102e+10   500         Mouse     Wired Mouse
# 201  進貨量     3.10102e+10   200         Mouse     Wired Mouse
# 202  進貨量       3.103e+10   120         Mouse  Wireless Mouse
# 203  進貨量       3.103e+10    40         Mouse  Wireless Mouse
# 204  進貨量       3.103e+10   120         Mouse  Wireless Mouse
# 205  進貨量     3.10301e+10  2000         Mouse  Wireless Mouse
# 206  進貨量     3.10301e+10   800         Mouse  Wireless Mouse
# 207  進貨量     3.10301e+10   800         Mouse  Wireless Mouse
# 208  進貨量     3.10301e+10  1000         Mouse  Wireless Mouse
# 209  進貨量     3.10301e+10   400         Mouse  Wireless Mouse
# 210  進貨量     3.10301e+10   300         Mouse  Wireless Mouse
# 211  進貨量     3.10301e+10   300         Mouse  Wireless Mouse
# 212  進貨量       3.109e+10   200         Other           Other
# 213  進貨量        3.13e+10   400  Keyboard/K+M        Wired KB
# 214  進貨量        3.13e+10   680  Keyboard/K+M        Wired KB
# 215  進貨量     3.13007e+10   240  Keyboard/K+M        Wired KB
# 216  進貨量       3.131e+10   500  Keyboard/K+M        Wired KB
# 217  進貨量     3.13105e+10    60        Gaming       Gaming KB
# 218  進貨量     3.13105e+10    60        Gaming       Gaming KB
# 219  進貨量       3.134e+10   200  Keyboard/K+M   Wireless K+M
# 220  進貨量       3.171e+10   200       Headset         Headset
# 221  進貨量       3.171e+10   300       Headset         Headset
# 222  進貨量     3.17102e+10  1000       Headset         Headset
# 223  進貨量       3.173e+10  1200       Speaker     USB Speaker
# 224  進貨量       3.173e+10  1200       Speaker     USB Speaker
# 225  進貨量       3.173e+10   600       Speaker     USB Speaker
# 226  進貨量     3.22002e+10   100       Web Cam         Web Cam
#
# 0           Sls CD4 Desc#                   Product Desc#  Year Month
# 200               DX-150X         RS,DX-150X,USB,BLACK,G5  2020     2
# 201                DX-180          RS,DX-180,USB,BLACK,G5  2020     2
# 202              ECO-8100  RS,ECO-8100,Black,Channel,GM-!  2020     2
# 203              ECO-8100  RS,ECO-8100,Blue,Channel,GM-1!  2020     2
# 204              ECO-8100  RS,ECO-8100,Red,Channel,GM-16!  2020     2
# 205               NX-7000  RS,NX-7000,ANTI-FAKE,BLK,G5,H!  2020     2
# 206               NX-7000  RS,NX-7000,ANTI-FAKE,WHITE,G5!  2020     2
# 207               NX-7000  RS,NX-7000,ANTI-FAKE,BLUE,G5,!  2020     2
# 208               NX-7000  RS,NX-7000,ANTI-FAKE,RED,G5,H!  2020     2
# 209               NX-7000  RS,NX-7000,ANTI-FAKE,GREEN,G5!  2020     2
# 210               NX-7010  RS,NX-7010,USB,TURQUOISE,BLIS!  2020     2
# 211               NX-7010   RS,NX-7010,USB,WH+RED,BLISTER  2020     2
# 212  Media Pointer 100 V3   RS,MEDIA POINTER 100,RUN CARD  2020     2
# 213           NumPad i130  RS,NumPad i130,Black,USB,GK-1!  2020     2
# 214          Smart KB-102   RS,Smart KB-102,BLK,USB,US,G!  2020     2
# 215          LuxeMate 100   RS,LUXEMATE 100,USB,BLK,US,CB  2020     2
# 216          SlimStar 230     RS2,SS 230,US,BLK,GK-190007  2020     2
# 217         Scorpion K215  RS,SCORPION K215,USB,BLK,US,C!  2020     2
# 218         Scorpion K220  RS,SCORPION K220,USB,BLK,US,C!  2020     2
# 219         Smart KM-8200  RS2,Smart KM-8200,BLK,USB,US,!  2020     2
# 220                HS-05A                       RS,HS-05A  2020     2
# 221               HS-04SU                      RS,HS-04SU  2020     2
# 222               HS-200C                      RS,HS-200C  2020     2
# 223      USB SoundBar 100  RS2,USB SoundBar 100,BLK,GP-1!  2020     2
# 224              SP-HF180  RS2,SP-HF180,WOOD,USB,GP-1900!  2020     2
# 225              SP-HF180  RS2,SP-HF180,BLK,USB,GP-190006  2020     2
# 226      FaceCam 1000X V2             RS,FACECAM 1000X V2  2020     2

# %%
df.pivot_table(    #前面可以加篩選(excel樞紐的左上)
               columns = ['進銷存'],   #欄變數(excel樞紐的右上)
               index = ['LargeCat','MediumCat'],  #列變數(excel樞紐的左下)
               values = ['Qty'],
               aggfunc=np.sum,
               #margins=True,  #添加所有行/列小計/總計
               #margins_name='Total', #當margins=True時，更改欄位名稱，默認為All
               fill_value=0  #用"某值"填滿遺漏值
               #dropna=True  #丟棄NA值
                )
# Out:
# 0                                          Qty
# 進銷存                                        存貨量    進貨量   銷貨量
# LargeCat     MediumCat
# Gaming       Gaming KB                     805   1000   180
#              Gaming Mouse                 4206   1900   193
# Headset      BT Headset                    191      0     0
#              Headset                     14251  10100   866
#              In-ear Headset/Headphones    7345   4260     0
# K+M+S        K+M+S                        4759      0   675
# Keyboard/K+M Wired K+M                    6343   3039   378
#              Wired KB                    45220  38838  6934
#              Wireless K+M                 3556   1881   144
# Mouse        Wired Mouse                103569  61540  6987
#              Wireless Mouse              77782  49160  5073
# Other        Other                        5367    420    11
# Speaker      2.0 Speaker                  7050   5660     0
#              2.1 Speaker                   241      0     0
#              BT Speaker                   1823    253     0
#              USB Speaker                  2201  14121  1462
# Web Cam      Web Cam                       488    600   163
