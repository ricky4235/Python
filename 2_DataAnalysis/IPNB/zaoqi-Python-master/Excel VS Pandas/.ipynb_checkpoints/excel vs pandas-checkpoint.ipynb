# %% [markdown]
# ## Excel vs Pandas
# ### 制作：刘早起
# ### 公众号：早起Python

# %% [markdown]
# ## 数据读取

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
#将示例数据.xlsx放在该Notebook同一文件夹下
pd.read_excel("示例数据.xlsx")
# Out:
#                    创建时间  地址    岗位  学历                          技能要求   工作经验  \
# 0   2020-03-16 12:28:11  广州  数据开发  本科      ['Hive', '数据挖掘', '数据分析']   3-5年
# 1   2020-03-16 12:39:03  广州  数据分析  本科               ['数据分析', '数据库']   1-3年
# 2   2020-03-16 12:01:37  广州  数据分析  本科                ['数据分析', '商业']  应届毕业生
# 3   2020-03-16 11:19:51  广州  数据分析  本科        ['SQL', '数据分析', '数据库']   3-5年
# 4   2020-03-16 11:18:49  广州  数据分析  大专                      ['数据分析']   1-3年
# ..                  ...  ..   ...  ..                           ...    ...
# 820 2020-03-16 11:20:44  深圳  数据分析  本科                            []   1年以下
# 821 2020-03-16 11:20:42  深圳  数据开发  本科                            []  应届毕业生
# 822 2020-03-16 10:33:46  深圳  数据分析  本科  ['BI', '数据分析', 'SQL', '数据库']   3-5年
# 823 2020-03-16 11:20:43  深圳  数据开发  本科                            []     不限
# 824 2020-03-16 10:37:24  深圳  数据分析  本科                            []     不限
#
#         薪资水平
# 0    20000.0
# 1    13000.0
# 2     8000.0
# 3    20000.0
# 4     8000.0
# ..       ...
# 820  11500.0
# 821   4500.0
# 822  16500.0
# 823  11500.0
# 824   3000.0
#
# [825 rows x 7 columns]

# %% [markdown]
# ## 数据生成

# %%
data = pd.DataFrame(np.random.rand(10,2))
data
# Out:
#           0         1
# 0  0.622167  0.381296
# 1  0.529402  0.539190
# 2  0.029463  0.910954
# 3  0.879612  0.403374
# 4  0.318232  0.511158
# 5  0.674114  0.266865
# 6  0.818853  0.762009
# 7  0.375183  0.519102
# 8  0.650106  0.356870
# 9  0.315061  0.449215

# %% [markdown]
# ## 数据保存

# %%
data.to_excel("测试数据.xlsx")

# %% [markdown]
# ## 数据筛选

# %%
df = pd.read_excel("示例数据.xlsx")
df[df['薪资水平']>5000]
# Out:
#                    创建时间  地址    岗位  学历                          技能要求   工作经验  \
# 0   2020-03-16 12:28:11  广州  数据开发  本科      ['Hive', '数据挖掘', '数据分析']   3-5年
# 1   2020-03-16 12:39:03  广州  数据分析  本科               ['数据分析', '数据库']   1-3年
# 2   2020-03-16 12:01:37  广州  数据分析  本科                ['数据分析', '商业']  应届毕业生
# 3   2020-03-16 11:19:51  广州  数据分析  本科        ['SQL', '数据分析', '数据库']   3-5年
# 4   2020-03-16 11:18:49  广州  数据分析  大专                      ['数据分析']   1-3年
# ..                  ...  ..   ...  ..                           ...    ...
# 817 2020-03-16 11:20:42  深圳  数据分析  本科                            []   1-3年
# 819 2020-03-16 11:20:44  深圳  数据分析  本科                            []   1-3年
# 820 2020-03-16 11:20:44  深圳  数据分析  本科                            []   1年以下
# 822 2020-03-16 10:33:46  深圳  数据分析  本科  ['BI', '数据分析', 'SQL', '数据库']   3-5年
# 823 2020-03-16 11:20:43  深圳  数据开发  本科                            []     不限
#
#         薪资水平
# 0    20000.0
# 1    13000.0
# 2     8000.0
# 3    20000.0
# 4     8000.0
# ..       ...
# 817  11500.0
# 819  15000.0
# 820  11500.0
# 822  16500.0
# 823  11500.0
#
# [776 rows x 7 columns]

# %% [markdown]
# ## 数据插入

# %%
bins = [0,10000,max(df['薪资水平'])]
group_names = ['低','高']
df['new_col'] = pd.cut(df['薪资水平'], bins, labels=group_names)
df
# Out:
#                    创建时间  地址    岗位  学历                          技能要求   工作经验  \
# 0   2020-03-16 12:28:11  广州  数据开发  本科      ['Hive', '数据挖掘', '数据分析']   3-5年
# 1   2020-03-16 12:39:03  广州  数据分析  本科               ['数据分析', '数据库']   1-3年
# 2   2020-03-16 12:01:37  广州  数据分析  本科                ['数据分析', '商业']  应届毕业生
# 3   2020-03-16 11:19:51  广州  数据分析  本科        ['SQL', '数据分析', '数据库']   3-5年
# 4   2020-03-16 11:18:49  广州  数据分析  大专                      ['数据分析']   1-3年
# ..                  ...  ..   ...  ..                           ...    ...
# 820 2020-03-16 11:20:44  深圳  数据分析  本科                            []   1年以下
# 821 2020-03-16 11:20:42  深圳  数据开发  本科                            []  应届毕业生
# 822 2020-03-16 10:33:46  深圳  数据分析  本科  ['BI', '数据分析', 'SQL', '数据库']   3-5年
# 823 2020-03-16 11:20:43  深圳  数据开发  本科                            []     不限
# 824 2020-03-16 10:37:24  深圳  数据分析  本科                            []     不限
#
#         薪资水平 new_col
# 0    20000.0       高
# 1    13000.0       高
# 2     8000.0       低
# 3    20000.0       高
# 4     8000.0       低
# ..       ...     ...
# 820  11500.0       高
# 821   4500.0       低
# 822  16500.0       高
# 823  11500.0       高
# 824   3000.0       低
#
# [825 rows x 8 columns]

# %% [markdown]
# ## 数据删除

# %%
del df['new_col']
df
# Out:
#                    创建时间  地址    岗位  学历                          技能要求   工作经验  \
# 0   2020-03-16 12:28:11  广州  数据开发  本科      ['Hive', '数据挖掘', '数据分析']   3-5年
# 1   2020-03-16 12:39:03  广州  数据分析  本科               ['数据分析', '数据库']   1-3年
# 2   2020-03-16 12:01:37  广州  数据分析  本科                ['数据分析', '商业']  应届毕业生
# 3   2020-03-16 11:19:51  广州  数据分析  本科        ['SQL', '数据分析', '数据库']   3-5年
# 4   2020-03-16 11:18:49  广州  数据分析  大专                      ['数据分析']   1-3年
# ..                  ...  ..   ...  ..                           ...    ...
# 820 2020-03-16 11:20:44  深圳  数据分析  本科                            []   1年以下
# 821 2020-03-16 11:20:42  深圳  数据开发  本科                            []  应届毕业生
# 822 2020-03-16 10:33:46  深圳  数据分析  本科  ['BI', '数据分析', 'SQL', '数据库']   3-5年
# 823 2020-03-16 11:20:43  深圳  数据开发  本科                            []     不限
# 824 2020-03-16 10:37:24  深圳  数据分析  本科                            []     不限
#
#         薪资水平
# 0    20000.0
# 1    13000.0
# 2     8000.0
# 3    20000.0
# 4     8000.0
# ..       ...
# 820  11500.0
# 821   4500.0
# 822  16500.0
# 823  11500.0
# 824   3000.0
#
# [825 rows x 7 columns]

# %% [markdown]
# ## 数据排序

# %%
df1 = df
df1.sort_values("薪资水平",ascending=False)
df1
# Out:
#                    创建时间  地址    岗位  学历                          技能要求   工作经验  \
# 0   2020-03-16 12:28:11  广州  数据开发  本科      ['Hive', '数据挖掘', '数据分析']   3-5年
# 1   2020-03-16 12:39:03  广州  数据分析  本科               ['数据分析', '数据库']   1-3年
# 2   2020-03-16 12:01:37  广州  数据分析  本科                ['数据分析', '商业']  应届毕业生
# 3   2020-03-16 11:19:51  广州  数据分析  本科        ['SQL', '数据分析', '数据库']   3-5年
# 4   2020-03-16 11:18:49  广州  数据分析  大专                      ['数据分析']   1-3年
# ..                  ...  ..   ...  ..                           ...    ...
# 820 2020-03-16 11:20:44  深圳  数据分析  本科                            []   1年以下
# 821 2020-03-16 11:20:42  深圳  数据开发  本科                            []  应届毕业生
# 822 2020-03-16 10:33:46  深圳  数据分析  本科  ['BI', '数据分析', 'SQL', '数据库']   3-5年
# 823 2020-03-16 11:20:43  深圳  数据开发  本科                            []     不限
# 824 2020-03-16 10:37:24  深圳  数据分析  本科                            []     不限
#
#         薪资水平
# 0    20000.0
# 1    13000.0
# 2     8000.0
# 3    20000.0
# 4     8000.0
# ..       ...
# 820  11500.0
# 821   4500.0
# 822  16500.0
# 823  11500.0
# 824   3000.0
#
# [825 rows x 7 columns]

# %% [markdown]
# ## 缺失值处理

# %%
df.isnull().sum()
# Out:
# 创建时间    0
# 地址      0
# 岗位      0
# 学历      0
# 技能要求    0
# 工作经验    0
# 薪资水平    2
# dtype: int64

# %%
df1 = df
df1 = df1.fillna(axis=0,method='ffill')
df1
# Out:
#                    创建时间  地址    岗位  学历                          技能要求   工作经验  \
# 0   2020-03-16 12:28:11  广州  数据开发  本科      ['Hive', '数据挖掘', '数据分析']   3-5年
# 1   2020-03-16 12:39:03  广州  数据分析  本科               ['数据分析', '数据库']   1-3年
# 2   2020-03-16 12:01:37  广州  数据分析  本科                ['数据分析', '商业']  应届毕业生
# 3   2020-03-16 11:19:51  广州  数据分析  本科        ['SQL', '数据分析', '数据库']   3-5年
# 4   2020-03-16 11:18:49  广州  数据分析  大专                      ['数据分析']   1-3年
# ..                  ...  ..   ...  ..                           ...    ...
# 820 2020-03-16 11:20:44  深圳  数据分析  本科                            []   1年以下
# 821 2020-03-16 11:20:42  深圳  数据开发  本科                            []  应届毕业生
# 822 2020-03-16 10:33:46  深圳  数据分析  本科  ['BI', '数据分析', 'SQL', '数据库']   3-5年
# 823 2020-03-16 11:20:43  深圳  数据开发  本科                            []     不限
# 824 2020-03-16 10:37:24  深圳  数据分析  本科                            []     不限
#
#         薪资水平
# 0    20000.0
# 1    13000.0
# 2     8000.0
# 3    20000.0
# 4     8000.0
# ..       ...
# 820  11500.0
# 821   4500.0
# 822  16500.0
# 823  11500.0
# 824   3000.0
#
# [825 rows x 7 columns]

# %% [markdown]
# ## 数据去重

# %%
df.drop_duplicates(['创建时间'],inplace=True)
df
# Out:
#                    创建时间  地址    岗位  学历                              技能要求  \
# 0   2020-03-16 12:28:11  广州  数据开发  本科          ['Hive', '数据挖掘', '数据分析']
# 1   2020-03-16 12:39:03  广州  数据分析  本科                   ['数据分析', '数据库']
# 2   2020-03-16 12:01:37  广州  数据分析  本科                    ['数据分析', '商业']
# 3   2020-03-16 11:19:51  广州  数据分析  本科            ['SQL', '数据分析', '数据库']
# 4   2020-03-16 11:18:49  广州  数据分析  大专                          ['数据分析']
# ..                  ...  ..   ...  ..                               ...
# 811 2020-03-16 11:03:17  深圳  数据开发  本科  ['Hive', '数据分析', '数据仓库', '信息安全']
# 812 2020-03-16 11:03:03  深圳  数据开发  本科                  ['数据挖掘', '数据分析']
# 815 2020-03-16 11:00:56  深圳  数据分析  本科      ['BI', '数据分析', 'SQL', '数据库']
# 817 2020-03-16 11:20:42  深圳  数据分析  本科                                []
# 824 2020-03-16 10:37:24  深圳  数据分析  本科                                []
#
#       工作经验     薪资水平
# 0     3-5年  20000.0
# 1     1-3年  13000.0
# 2    应届毕业生   8000.0
# 3     3-5年  20000.0
# 4     1-3年   8000.0
# ..     ...      ...
# 811   3-5年  37000.0
# 812     不限  30000.0
# 815  5-10年  45000.0
# 817   1-3年  11500.0
# 824     不限   3000.0
#
# [629 rows x 7 columns]

# %% [markdown]
# ## 格式修改

# %%
df1 = df
df1['创建时间'] = df1['创建时间'].dt.strftime('%Y-%m-%d')
df1
# Out:
#            创建时间  地址    岗位  学历                              技能要求   工作经验  \
# 0    2020-03-16  广州  数据开发  本科          ['Hive', '数据挖掘', '数据分析']   3-5年
# 1    2020-03-16  广州  数据分析  本科                   ['数据分析', '数据库']   1-3年
# 2    2020-03-16  广州  数据分析  本科                    ['数据分析', '商业']  应届毕业生
# 3    2020-03-16  广州  数据分析  本科            ['SQL', '数据分析', '数据库']   3-5年
# 4    2020-03-16  广州  数据分析  大专                          ['数据分析']   1-3年
# ..          ...  ..   ...  ..                               ...    ...
# 811  2020-03-16  深圳  数据开发  本科  ['Hive', '数据分析', '数据仓库', '信息安全']   3-5年
# 812  2020-03-16  深圳  数据开发  本科                  ['数据挖掘', '数据分析']     不限
# 815  2020-03-16  深圳  数据分析  本科      ['BI', '数据分析', 'SQL', '数据库']  5-10年
# 817  2020-03-16  深圳  数据分析  本科                                []   1-3年
# 824  2020-03-16  深圳  数据分析  本科                                []     不限
#
#         薪资水平
# 0    20000.0
# 1    13000.0
# 2     8000.0
# 3    20000.0
# 4     8000.0
# ..       ...
# 811  37000.0
# 812  30000.0
# 815  45000.0
# 817  11500.0
# 824   3000.0
#
# [629 rows x 7 columns]

# %% [markdown]
# ## 数据交换

# %%
cols = df.columns[[0,2,1,3,4,5,6]]
df1 = df[cols]
df1
# Out:
#            创建时间    岗位  地址  学历                              技能要求   工作经验  \
# 0    2020-03-16  数据开发  广州  本科          ['Hive', '数据挖掘', '数据分析']   3-5年
# 1    2020-03-16  数据分析  广州  本科                   ['数据分析', '数据库']   1-3年
# 2    2020-03-16  数据分析  广州  本科                    ['数据分析', '商业']  应届毕业生
# 3    2020-03-16  数据分析  广州  本科            ['SQL', '数据分析', '数据库']   3-5年
# 4    2020-03-16  数据分析  广州  大专                          ['数据分析']   1-3年
# ..          ...   ...  ..  ..                               ...    ...
# 811  2020-03-16  数据开发  深圳  本科  ['Hive', '数据分析', '数据仓库', '信息安全']   3-5年
# 812  2020-03-16  数据开发  深圳  本科                  ['数据挖掘', '数据分析']     不限
# 815  2020-03-16  数据分析  深圳  本科      ['BI', '数据分析', 'SQL', '数据库']  5-10年
# 817  2020-03-16  数据分析  深圳  本科                                []   1-3年
# 824  2020-03-16  数据分析  深圳  本科                                []     不限
#
#         薪资水平
# 0    20000.0
# 1    13000.0
# 2     8000.0
# 3    20000.0
# 4     8000.0
# ..       ...
# 811  37000.0
# 812  30000.0
# 815  45000.0
# 817  11500.0
# 824   3000.0
#
# [629 rows x 7 columns]

# %% [markdown]
# ## 数据合并

# %%
df['合并列'] = df['地址'] + df['岗位']
df
# Out:
#            创建时间  地址    岗位  学历                              技能要求   工作经验  \
# 0    2020-03-16  广州  数据开发  本科          ['Hive', '数据挖掘', '数据分析']   3-5年
# 1    2020-03-16  广州  数据分析  本科                   ['数据分析', '数据库']   1-3年
# 2    2020-03-16  广州  数据分析  本科                    ['数据分析', '商业']  应届毕业生
# 3    2020-03-16  广州  数据分析  本科            ['SQL', '数据分析', '数据库']   3-5年
# 4    2020-03-16  广州  数据分析  大专                          ['数据分析']   1-3年
# ..          ...  ..   ...  ..                               ...    ...
# 811  2020-03-16  深圳  数据开发  本科  ['Hive', '数据分析', '数据仓库', '信息安全']   3-5年
# 812  2020-03-16  深圳  数据开发  本科                  ['数据挖掘', '数据分析']     不限
# 815  2020-03-16  深圳  数据分析  本科      ['BI', '数据分析', 'SQL', '数据库']  5-10年
# 817  2020-03-16  深圳  数据分析  本科                                []   1-3年
# 824  2020-03-16  深圳  数据分析  本科                                []     不限
#
#         薪资水平     合并列
# 0    20000.0  广州数据开发
# 1    13000.0  广州数据分析
# 2     8000.0  广州数据分析
# 3    20000.0  广州数据分析
# 4     8000.0  广州数据分析
# ..       ...     ...
# 811  37000.0  深圳数据开发
# 812  30000.0  深圳数据开发
# 815  45000.0  深圳数据分析
# 817  11500.0  深圳数据分析
# 824   3000.0  深圳数据分析
#
# [629 rows x 8 columns]

# %% [markdown]
# ## 数据拆分

# %%
df['技能要求'].str.split(',',expand=True)
# Out:
#             0         1         2         3
# 0     ['Hive'    '数据挖掘'   '数据分析']      None
# 1     ['数据分析'    '数据库']      None      None
# 2     ['数据分析'     '商业']      None      None
# 3      ['SQL'    '数据分析'    '数据库']      None
# 4    ['数据分析']      None      None      None
# ..        ...       ...       ...       ...
# 811   ['Hive'    '数据分析'    '数据仓库'   '信息安全']
# 812   ['数据挖掘'   '数据分析']      None      None
# 815     ['BI'    '数据分析'     'SQL'    '数据库']
# 817        []      None      None      None
# 824        []      None      None      None
#
# [629 rows x 4 columns]

# %% [markdown]
# ## 数据分组

# %%
df.groupby("学历").mean()
# Out:
#             薪资水平
# 学历
# 不限  18647.058824
# 大专  11775.000000
# 本科  19537.950664
# 硕士  20134.615385

# %% [markdown]
# ## 数据计算

# %%
len(df[df["薪资水平"]>10000])
# Out:
# 518

# %% [markdown]
# ## 数据统计

# %%
df["薪资水平"].describe()
# Out:
# count      627.000000
# mean     19019.138756
# std       9696.823558
# min       1000.000000
# 25%      12500.000000
# 50%      17500.000000
# 75%      25000.000000
# max      60000.000000
# Name: 薪资水平, dtype: float64

# %% [markdown]
# ## 数据可视化

# %%
# %matplotlib inline
df["薪资水平"].hist()

# %% [markdown]
# ## 数据抽样

# %%
df.sample(20)
# Out:
#            创建时间  地址    岗位  学历                            技能要求   工作经验     薪资水平  \
# 280  2020-03-16  北京  数据分析  不限                ['数据分析', '数据运营']   1-3年  20000.0
# 171  2020-03-16  杭州  数据分析  本科                              []   1-3年  17500.0
# 653  2020-03-16  深圳    运营  本科                              []   3-5年  30000.0
# 57   2020-03-16  广州  数据分析  本科  ['数据分析', '数据运营', '数据库', 'DBA']   1-3年   6000.0
# 788  2020-03-11  深圳  数据开发  本科                        ['数据分析']     不限  10000.0
# 605  2020-03-16  深圳    运营  本科                  ['数据分析', '商务']   3-5年  13500.0
# 180  2020-03-16  杭州    运营  本科                ['数据分析', '产品运营']   3-5年  15000.0
# 100  2020-03-16  广州  数据开发  本科                ['数据挖掘', '数据分析']   1-3年  12500.0
# 593  2020-03-16  深圳  数据分析  本科                        ['数据分析']   1-3年   1500.0
# 800  2020-02-26  深圳  数据分析  本科   ['数据分析', '数据运营', '可视化', 'BI']  应届毕业生   7000.0
# 420  2020-03-16  北京  数据分析  本科                          ['产品']   3-5年  16000.0
# 483  2020-03-16  上海  数据分析  本科                ['数据分析', '数据运营']   3-5年  16000.0
# 414  2020-03-16  北京  数据分析  本科                              []   3-5年  12500.0
# 606  2020-03-15  深圳  数据分析  本科                        ['数据分析']   3-5年  17500.0
# 128  2020-03-13  广州  数据分析  本科                 ['数据分析', 'SQL']   1-3年  15000.0
# 145  2020-03-13  广州  数据分析  硕士                        ['数据分析']     不限  10000.0
# 341  2020-03-16  北京  数据开发  本科                        ['数据仓库']  5-10年  47500.0
# 156  2020-01-10  广州  数据开发  硕士          ['算法', '数据挖掘', '数据分析']   1-3年  10500.0
# 328  2020-03-15  北京  数据分析  本科                        ['数据分析']   1-3年  22500.0
# 283  2020-03-16  北京    运营  本科                        ['数据分析']   1-3年  15000.0
#
#         合并列
# 280  北京数据分析
# 171  杭州数据分析
# 653    深圳运营
# 57   广州数据分析
# 788  深圳数据开发
# 605    深圳运营
# 180    杭州运营
# 100  广州数据开发
# 593  深圳数据分析
# 800  深圳数据分析
# 420  北京数据分析
# 483  上海数据分析
# 414  北京数据分析
# 606  深圳数据分析
# 128  广州数据分析
# 145  广州数据分析
# 341  北京数据开发
# 156  广州数据开发
# 328  北京数据分析
# 283    北京运营

# %% [markdown]
# ## 数据透视表

# %%
pd.pivot_table(df,index=["地址","学历"],values=["薪资水平"])
# Out:
#                薪资水平
# 地址 学历
# 上海 不限  17000.000000
#    大专  10000.000000
#    本科  19464.285714
#    硕士  20642.857143
# 北京 不限  22833.333333
#    大专  19000.000000
#    本科  23726.086957
#    硕士  27500.000000
# 广州 不限  17750.000000
#    大专  10700.000000
#    本科  14916.666667
#    硕士   7666.666667
# 杭州 不限  17733.333333
#    大专  16625.000000
#    本科  20753.623188
#    硕士  14000.000000
# 深圳 不限  18833.333333
#    大专  10437.500000
#    本科  19313.793103
#    硕士  23150.000000

# %% [markdown]
# ## VLOOKUP

# %%
df1 = pd.read_excel("vlookup.xlsx")
df1
# Out:
#   序号  科目   成绩  排名  Unnamed: 4 序号.1  科目.1  成绩.1  排名.1
# 0  A  语文   80   8         NaN    C   NaN   NaN   NaN
# 1  B  数学   70   2         NaN  NaN   NaN   NaN   NaN
# 2  C  英语   60   4         NaN  NaN   NaN   NaN   NaN
# 3  D  政治   50   5         NaN  NaN   NaN   NaN   NaN
# 4  E  地理   90   6         NaN  NaN   NaN   NaN   NaN
# 5  F  化学  100   1         NaN  NaN   NaN   NaN   NaN
# 6  G  生物   77   3         NaN  NaN   NaN   NaN   NaN

# %%
df2 = df1.iloc[:, :4]
df2
# Out:
#   序号  科目   成绩  排名
# 0  A  语文   80   8
# 1  B  数学   70   2
# 2  C  英语   60   4
# 3  D  政治   50   5
# 4  E  地理   90   6
# 5  F  化学  100   1
# 6  G  生物   77   3

# %%
df3 = df1[["序号.1","科目.1","成绩.1","排名.1"]] #後面要vlookup的資料
df3.columns = ["序号","科目","成绩","排名"]
df3 = df3.loc[0:0]  #只有一筆資料
df3
# Out:
#   序号  科目  成绩  排名
# 0  C NaN NaN NaN

# %%
df2 = df2.set_index("序号")
df2
# Out:
#     科目   成绩  排名
# 序号
# A   语文   80   8
# B   数学   70   2
# C   英语   60   4
# D   政治   50   5
# E   地理   90   6
# F   化学  100   1
# G   生物   77   3

# %%
df3 = df3.set_index("序号")
df3
# Out:
#     科目  成绩  排名
# 序号
# C  NaN NaN NaN

# %%
df3.update(df2)
df3
# Out:
#     科目    成绩   排名
# 序号
# C   英语  60.0  4.0
