# %%
import requests
from bs4 import BeautifulSoup
import time
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

url = 'https://www.amazon.com/s?k={0}&page={1}&qid=1583476177&ref=sr_pg_{1}'  #{0}:format後的第一個位置、{1}:第二個


def get_urls(url, query, start_page, end_page): #建立可自行輸入"查詢值"和"start~end_page"的url清單
    urls = []
    for page in range(start_page, end_page+1):
        urls.append(url.format(query, page))    #query帶入url的{0}、page帶入{1}
    return urls

def get_resource(url):
    headers = {"user-agent": "Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.122 Mobile Safari/537.36"}
    res = requests.get(url, headers=headers)
    if res.status_code == requests.codes.ok:
        print("請求成功")
        return BeautifulSoup(res.text, "lxml")
    else:
        return print("請求失敗")
    
def get_goods(soup):
    goods = []
    rows = soup.find("span", "rush-component s-latency-cf-section").find("div","s-result-list s-search-results sg-row").find_all("div", "sg-row")
    for row in rows:
        try:
            name = row.find("span", "a-size-medium a-color-base a-text-normal").text
        except:
            name = None
        try:
            price = row.find("span", "a-color-base").text
        except:
            price = None
    
        good = [name, price]
        goods.append(good)
    return goods

def bot(urls):
    all_goods = [["品名", "價格"]]  #巢狀清單
    
    page = 1
    for url in urls:
        print("抓取: 第" + str(page) + "頁 網路資料中...")
        page = page + 1
        soup = get_resource(url)
        goods = get_goods(soup)
        all_goods = all_goods + goods
        print("等待3秒鐘...")
        if soup.find("li", class_="a-disabled a-last"):
            break   #已經沒有下一頁
        time.sleep(3)
    return all_goods

if __name__ == "__main__":
#get_urls
    urls = get_urls(url, 'logitech', 1, 1)
    print(urls)
#get_resource
    goods = bot(urls)
    df = pd.DataFrame(goods)      #用dataframe列出
    print(df)
# Out:
# ['https://www.amazon.com/s?k=logitech&page=1&qid=1583476177&ref=sr_pg_1']
# 抓取: 第1頁 網路資料中...
# 請求成功
# 等待3秒鐘...
#        0                                                  1
# 0     品名                                                 價格
# 1   None                                               None
# 2   None  Camera USB 2.8-12mm Varifocal Lens USB Camera ...
# 3   None                                               None
# 4   None  ZILINK 1080P Full HD Webcam, Computer and Lapt...
# 5   None                                               None
# 6   None                                               None
# 7   None   Logitech G502 HERO High Performance Gaming Mouse
# 8   None                               The 7 Best Keyboards
# 9   None                                               Best
# 10  None                                               None
# 11  None  Logitech HD Pro Webcam C920, Widescreen Video ...
# 12  None                                               None
# 13  None  Logitech MX Master 3 Advanced Wireless Mouse -...
# 14  None
# 15  None                                          Under $25
# 16  None                                               None
# 17  None  Logitech MX Master 2S Wireless Mouse – Use on ...
# 18  None                                               None
# 19  None  Logitech G Pro Wireless Gaming Mouse with Espo...
# 20  None                                               None
# 21  None  Logitech MX Keys Advanced Wireless Illuminated...
# 22  None                                               None
# 23  None  Logitech MX Master Wireless Mouse – High-Preci...
# 24  None                                               None
# 25  None  Webcamera usb 2MP 5-50mm Varifocal Lens USB Ca...
# 26  None                                               None
# 27  None  Logitech MX Anywhere 2S Wireless Mouse – Use O...
# 28  None                                               None
# 29  None  Logitech Dual-Motor Feedback Driving Force G29...
# 30  None                                               None
# 31  None  Logitech MK345 Wireless Combo – Full-sized Key...
# 32  None                                               None
# 33  None  Logitech MK545 Advanced Wireless Keyboard and ...
# 34  None                                               None
# 35  None  Logitech M510 Wireless Computer Mouse – Comfor...
# 36  None                                               None
# 37  None  Logitech G502 LIGHTSPEED Wireless Gaming Mouse...
# 38  None                                               None
# 39  None  Logitech MK710 Wireless Keyboard and Mouse Com...
