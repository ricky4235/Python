# %%
import requests
from bs4 import BeautifulSoup
import time
import csv

url  = "https://www.amazon.com/stores/page/D3DB9423-BA6A-4ADC-8E17-C788DD52A2F9?ingress=0&visitId=c7e247ba-88d9-4be7-b52d-77dee1317f21&lp_slot=auto-sparkle-hsa-tetris&store_ref=SB_A10245962MPT6BZPXZHS0&pg=1" #Speaker

headers = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
           "AppleWebKit/537.36 (KHTML, like Gecko)"
           "Chrome/63.0.3239.132 Safari/537.36"}
res = requests.get(url, headers=headers)

soup = BeautifulSoup(res.text, "html.parser")


goods = []
rows = soup.find_all("li", class_="style__itemOuter__2dxew")

for row in rows:

    name = row.find("a", class_="style__title__3Z2Cu").text  
    star = row.find("span", class_="a-icon-alt").text
    reviews = row.find("span", class_="style__reviewCount__2jU9D").text
    price_int = row.find("span", class_="style__whole__3EZEk").text
    price_decimal = row.find("span", class_="style__fractional__iPo3s").text
    price= price_int + "." + price_decimal

    good= [name, star, reviews, price]
    goods.append(good)
goods
# Out:
# []

# %%
import requests
from bs4 import BeautifulSoup
import time
import csv

url  = "https://www.amazon.com/stores/page/D3DB9423-BA6A-4ADC-8E17-C788DD52A2F9?ingress=0&visitId=c7e247ba-88d9-4be7-b52d-77dee1317f21&lp_slot=auto-sparkle-hsa-tetris&store_ref=SB_A10245962MPT6BZPXZHS0&pg=1" #Speaker

headers = {"user-agent": "Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N)"
           "AppleWebKit/537.36 (KHTML, like Gecko)"
           "Chrome/80.0.3987.122 Mobile Safari/537.36"}
              
res = requests.get(url, headers=headers)

soup = BeautifulSoup(res.text, "html.parser")


soup
# Out:
# <!DOCTYPE doctype html>
# <html class="a-no-js a-touch a-mobile" data-19ax5a9jf="mongoose" lang="en-us"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta content="width=device-width, maximum-scale=1, minimum-scale=1, initial-scale=1, user-scalable=no, shrink-to-fit=no" name="viewport"/><meta charset="utf-8"/>
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script><!-- sp:feature:cs-optimization -->
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.amazon.com/stores/slot/xcogi4l0ey?ingress=0&visitId=8ddc23e0-feb6-4a3e-9846-63854aa6a633&slashargs=&pg=1&lp_slot=auto-sparkle-hsa-tetris&store_ref=SB_A10245962MPT6BZPXZHS0&pageId=D3DB9423-BA6A-4ADC-8E17-C788DD52A2F9"
headers = {"user-agent": "Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.122 Mobile Safari/537.36"}
res = requests.get(url, headers=headers)
soup = BeautifulSoup(res.text, "html.parser")
resp = soup.find("script")
resp
# Out:
# <script>
#   P.when("stores-widget-productgrid").execute( function (Widget) {
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.lazada.co.th/catalog/?spm=a2o4m.home.search.1.1125515ftmsdov&q=genius%20mouse&_keyori=ss&from=search_history&sugg=genius%20mouse_0_1"
#headers = {"user-agent": "Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.122 Mobile Safari/537.36"}
res = requests.get(url)
soup = BeautifulSoup(res.text, "lxml")
soup
# Out:
# <!DOCTYPE html>
# <html lang="th">
# <head>
# <meta charset="utf-8"/>
# <meta content="a2o4m" name="data-spm"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width" name="viewport"/>
# <link href="//laz-g-cdn.alicdn.com" rel="dns-prefetch"/>
# <link href="//laz-img-cdn.alicdn.com" rel="dns-prefetch"/>
# <title>genius mouse - ซื้อ genius mouse ราคาดีที่สุดค่ะ Thailand | www.lazada.co.th</title>
# <meta content="genius mouse Thailand - เลือกซื้อสินค้าได้ดีที่สุด genius mouse ออนไลน์ได้ที่ www.lazada.co.th" name="description"/>
# <meta content="25ZiIC89hBvAEL0Sgu7Ffw07GXU_d4CXtFvWyK3wMjo" name="google-site-verification"/>
# <meta content="noindex, follow" name="robots"/>
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.flipkart.com/search?q=logitech&sid=6bo%2Cai3%2C3oe&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_0_5_na_na_pr&otracker1=AS_QueryStore_OrganicAutoSuggest_0_5_na_na_pr&as-pos=0&as-type=RECENT&suggestionId=logitech%7Cin+Keyboards&requestId=45676ce1-76ce-47f3-832d-36d751606cac&as-searchtext=logit&p%5B%5D=facets.price_range.from%3DMin&p%5B%5D=facets.price_range.to%3DMax"
res = requests.get(url)
res.text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<link href="https://rukminim1.flixcart.com" rel="dns-prefetch" />\n\t<link href="https://img1a.flixcart.com" rel="dns-prefetch" />\n\t<link rel="stylesheet" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.0bf2d8.css" />\n\n\t<link rel="preload" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" as="image">\n\n\t<meta http-equiv="Content-type" content="text/html; charset=utf-8"/>\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n\t<meta property="fb:page_id" content="102988293558"/>\n\t<meta property="fb:admins" content="658873552,624500995,100000233612389"/>\n\t<meta name="robots" content="noodp" />\n\n\t<link rel=\'shortcut icon\' href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" />\n\n\t<link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/>\n\n\t<meta property="og:type" content="website"/>\n\t<meta name="og_site_name" pro
# ...
