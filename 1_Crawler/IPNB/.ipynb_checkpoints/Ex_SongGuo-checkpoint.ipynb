# %%
Ex_SongGuo

# %%
# 挑選第一筆資料作為範例

# %%
import requests
from requests_html import HTML
import pandas as pd
import re

# 輸入爬蟲網址與使用者資訊
url = 'https://www.pcone.com.tw/product/'
# 男生服飾
info = '327' 

# 加入使用者資訊(如使用什麼瀏覽器、作業系統...等資訊)模擬真實瀏覽網頁的情況
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

# 找出所有的商品連結
resp = requests.get(url + info, headers=headers)
html = HTML(html=resp.text)
a = html.find('a.product-list-item')

# 挑選第一筆資料作為範例
a = html.find('a.product-list-item')
resp = requests.get('https://www.pcone.com.tw/' + a[0].attrs['href'], headers=headers)
html = HTML(html=resp.text)


# # 店家名稱
html.find('a.store-name', first = True).text
# # 店家商品數量
# html.find('div.store-val', first = False)[0].attrs['data-val']
# # 店家評價
# html.find('div.store-val', first = False)[1].attrs['data-val']
# # 店家出貨天數
# html.find('div.store-val', first = False)[2].attrs['data-val']
# # 店家回覆率
# html.find('div.store-val', first = False)[3].attrs['data-val']
# # 產品名稱
# html.find('h1.product-name', first = True).text
# # 特價
# html.find('span.bind-lowest-price.discount',first = True).text
# # 原價
# html.find('span.original', first = True).text
# # 折數
# html.find('span.bind-discount-number.discount-number', first = True).text
# # 商品評分
# html.find('span.count > span', first = False)[0].text
# # 評價人數
# html.find('span.count > span', first = False)[1].text
# # 收藏人數
# html.find('div.count', first = False)[0].text
# # 提問人數
# html.find('div.count', first = False)[1].text
# # 商品分類
# html.find('div.breadcrumbs-set', first = True).text
# # 商品標籤
# html.find('div.tags', first = True).text
# # 商品連結
# 'https://www.pcone.com.tw' + a[0].attrs['href']
# Out:
# 'JU褲店'

# %%
# 遍歷【松果購物】各商品爬取細節_20200630完整版
1. 先取得搜尋頁數的網址List
2. 進入每個商品頁面
3. 爬取進入頁面之商品細節(這裡抓到直接用Pandas輸出)

# %%
import requests
from requests_html import HTML
import pandas as pd
import re

# 輸入爬蟲網址與使用者資訊
url = 'https://www.pcone.com.tw/product/'
# 男生服飾
info = '327' 

def get_soup(url):
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
    res = requests.get(url, headers=headers)
    return HTML(html=res.text)

resp = requests.get(url + info, headers=headers)
html = HTML(html=resp.text)
a = html.find('a.product-list-item')

# 定義ProdList函數，輸入商品分類編號，輸出該分類下所有商品連結
def ProdList(info):
    resp = requests.get(url + str(info), headers=headers)
    html = HTML(html=resp.text)
    return(html.find('a.product-list-item'))

# 定義Crawl_SongGuo函數，輸入商品網址，輸出該商品的各項屬性
def Crawl_SongGuo(info):
    resp = requests.get('https://www.pcone.com.tw/product/info/' + re.search(r'\d{12}',str(info)).group(), headers=headers)
    html = HTML(html=resp.text)
    print(re.search(r'\d{12}',str(info)).group())
    return(pd.DataFrame(
            data=[{
                '店家名稱':html.find('a.store-name',first = True).text,
                '店家商品數量':html.find('div.store-val',first = False)[0].attrs['data-val'],
                '店家評價':html.find('div.store-val',first = False)[1].attrs['data-val'],
                '店家出貨天數':html.find('div.store-val',first = False)[2].attrs['data-val'],
                '店家回覆率':html.find('div.store-val',first = False)[3].attrs['data-val'],
                '產品名稱':html.find('h1.product-name',first = True).text,
                '特價':html.find('span.bind-lowest-price.discount',first = True).text,
                '原價':html.find('span.original',first = True).text,
                '折數':html.find('span.bind-discount-number.discount-number',first = True).text,
                '商品評分':html.find('span.count > span',first = False)[0].text,
                '評價人數':html.find('span.count > span',first = False)[1].text,
                '收藏人數':html.find('div.count',first = False)[0].text,
                '提問人數':html.find('div.count',first = False)[1].text,
                '商品分類':html.find('div.breadcrumbs-set',first = True).text,
                '商品標籤':html.find('div.tags',first = True).text,
                '連結':'https://www.pcone.com.tw/product/info/' + re.search(r'\d{12}',str(info)).group()}],
            columns = ['店家名稱', '店家商品數量', '店家評價', '店家出貨天數', '店家回覆率',  '產品名稱', '特價', '原價', '折數',
                       '商品評分', '評價人數', '收藏人數','提問人數', '商品分類', '商品標籤', '連結']))

# 組合以上兩個函數，輸入商品分類的編號，即自動爬出所有商品的屬性，並將資料存在df中
prodlist = ProdList(327)
df = pd.DataFrame()
for i in range(len(prodlist)):
    df = df.append(Crawl_SongGuo(prodlist[i]), ignore_index=True)

# 檢視抓下來的資料
df

# 將df轉成excel並存在桌面上
#df.to_excel('SongGuo1.xlsx')
# Out:
# 171110560318
# 171017374825
# 160803815605
# 171123038939
# 171121549028
# 170904915739
# 170804025979
# 180812032390
# 180412079692
# 180319727479
# 180830936058
# 171211723688
# 180227532461
# 161129374107
# 171123817354
# 161116672594
# 181022235393
# 180420669552
# 171222909114
# 171019525742
# 171016219467
# 180328501473
# 181005230135
# 180202736725
# 171222248769
# 181211089811
# 181004934591
# 180502349395
# 170821256726
# 180817787611
# 180927920257
# 180822185737
# 170728706185
# 180927763049
# 170728713552
# 170728380553
# 180907070682
# 180926520487
# 181126272428
# 181113234175
# 181107972530
# 180716415751
# 181130354116
# 181012659095
# 180316249665
# 181106598475
# 181012535974
# 170728604391
# 171201266197
# 181120588306
# 181003483193
# 171213567750
# 181102797012
# 181204936842
#           店家名稱 店家商品數量 店家評價 店家出貨天數 店家回覆率  \
# 0         JU褲店     51  4.5    0.7  100%
# 1         JU褲店     51  4.5    0.7  100%
# 2     DR.MANGO    137  4.3    0.8  100%
# 3         JU褲店     51  4.5    0.7  100%
# 4       MR.J小舖    677  4.3      1  100%
# 5        草根王市集    129  4.5    0.8   99%
# 6    KASO SHOP     36  4.5    0.7   99%
# 7        草根王市集    129  4.5    0.8   99%
# 8     ANDYMAY2    421  4.5    0.6  100%
# 9         JU褲店     51  4.5    0.7  100%
# 10  ABC小中大尺碼服飾     59  4.4    0.6  100%
# 11  小魚創意行銷團購批發    105  4.5      1  100%
# 12    JIYI 購物館    479  4.4    0.9  100%
# 13        嚴選市集    100  4.6      1  100%
# 14        JU褲店     51  4.5    0.7  100%
# 15        林打商號     80  4.5    0.9  100%
# 16        JU褲店     51  4.5    0.7  100%
# 17     長野匠優質生活     92  4.5      1  100%
# 18        林打商號     80  4.5    0.9  100%
# 19   KASO SHOP     36  4.5    0.7   99%
# 20   KASO SHOP     36  4.5    0.7   99%
# 21    ANDYMAY2    421  4.5    0.6  100%
# 22         新番組     94  4.6    0.6   92%
# 23      哇哇哇購物網    369  4.4    0.9  100%
# 24         麥威夏    451  4.4      1   99%
# 25    DR.MANGO    137  4.3    0.8  100%
# 26       EHD宜紅    176  4.5    0.7  100%
# 27        JU褲店     51  4.5    0.7  100%
# 28      哇哇哇購物網    369  4.4    0.9  100%
# 29      仁麗有限公司     64  4.4    0.5  100%
# 30       恩銘企業社     65  4.5      1  100%
# 31      哇哇哇購物網    369  4.4    0.9  100%
# 32        三花棉業     61  4.7      1   99%
# 33        JU褲店     51  4.5    0.7  100%
# 34        三花棉業     61  4.7      1   99%
# 35        三花棉業     61  4.7      1   99%
# 36   KASO SHOP     36  4.5    0.7   99%
# 37        曼曼寶貝     28  4.4    0.8   98%
# 38   NEW FORCE    148  4.3    0.9  100%
# 39     SKIP四季織    123  4.7    0.8   95%
# 40       一家人服飾     30  4.7    0.7  100%
# 41      哇哇哇購物網    369  4.4    0.9  100%
# 42         新番組     94  4.6    0.6   92%
# 43        曼曼寶貝     28  4.4    0.8   98%
# 44   KASO SHOP     36  4.5    0.7   99%
# 45        曼曼寶貝     28  4.4    0.8   98%
# 46        曼曼寶貝     28  4.4    0.8   98%
# 47        三花棉業     61  4.7      1   99%
# 48    NEW STAR     90  4.6    0.6  100%
# 49      MR.J小舖    677  4.3      1  100%
# 50        JU褲店     51  4.5    0.7  100%
# 51       他她好鞋網     33  4.5    0.8   99%
# 52      i TYPE    162  4.4    0.7  100%
# 53         優衣購     84  4.8    0.6  100%
#
#                                                  產品名稱     特價     原價    折數  \
# 0                               二代歐巴迷彩！四季透氣工作褲 （彈力褲頭）   $390  $1680  2.3折
# 1                                         數位迷彩彈力戰術工作褲   $461  $1680  2.7折
# 2                                      拉鍊口袋速乾透氣休閒運動短褲   $186   $600  3.1折
# 3                                         冠軍款！透氣彈力工作褲   $399  $1980    2折
# 4                                         新款兩件式三穿保暖外套   $950  $9800    1折
# 5                                   美國軍規強固型尼龍腰帶(多色任選)   $159   $690  2.3折
# 6                         超高CP！經典熱賣款 美式高磅耐磨防割彈力多口袋工作褲   $454  $1880  2.4折
# 7                          【DaoDi】新眼鏡蛇釦軍規尼龍戰術腰帶(多色任選)   $125   $690  1.8折
# 8                                            日式無痕冰絲內褲    $87   $359  2.4折
# 9                                 歐巴迷彩輕量耐磨工作短褲（鬆緊帶褲頭）   $250  $1680  1.5折
# 10                     【ABC小中大尺碼服飾】大尺碼防風防水抗寒衝鋒褲 S-5XL   $499  $1280  3.9折
# 11                                  【小魚嚴選】冬季超保暖加厚羊毛男襪    $49   $299  1.6折
# 12                                     舒適透氣冰絲涼感網孔男士內褲    $69   $350    2折
# 13            【嚴選市集】軍規硬漢透氣耐磨工作靴 (工作鞋 馬丁鞋 馬丁靴 登山靴 軍靴 )   $499  $1680    3折
# 14                                      熱銷千件！美式彈力棉工作褲   $399  $1680  2.4折
# 15  大尺碼M~8XL情侶款登山戶外休閒褲 高品質防風防水禦寒衝鋒褲 登山釣魚機能工作褲 【16002】   $720  $1580  4.6折
# 49                                     超暖加厚登山防風雨抓絨衝鋒褲   $625  $1999  3.1折
# 50                                 MIT!抗縮水不起毛球保暖內刷毛棉褲   $369  $1280  2.9折
# 51                     (男) SHIBORDIN 多用途戶外靴 棕/黑 他她好鞋網   $891  $1390  6.4折
# 52                             【i TYPE】高質感純棉條紋質感四角男內褲    $50   $159  3.1折
# 53        【Pierre Cardin皮爾卡登】極速瞬熱陽離子暖絨長袖衫(圓領/V領 三色可選)   $303   $480  6.3折
#
#    商品評分 評價人數  收藏人數 提問人數               商品分類  \
# 0   4.5  740  2075  353      服飾婦幼 男性下身 工作褲
# 1   4.5  184   539   94   服飾婦幼 嬰幼玩具 其他嬰幼玩具
# 2   4.5  156   930   37  服飾婦幼 女性下身 休閒運動褲&裙
# 3   4.5  130   785   20   戶外休閒 戶外服飾 戶外機能下著
# 4   4.1   56   404   32   戶外休閒 戶外服飾 抗風防水外套
# 5   4.6  129   512   31     戶外休閒 行李箱 行李箱配件
# 6   4.7   56   355   39      服飾婦幼 男性下身 工作褲
# 7   4.6  181   487   24   戶外休閒 健身器材 中小健身器材
# 8   4.5   99   548   13     服飾婦幼 女性內睡衣 三角褲
# 9   4.6   55   364   31   戶外休閒 戶外服飾 戶外機能下著
# 10  4.8   35   348   44    服飾婦幼 女性下身 大尺碼褲裝
# 11  4.7   84   541   12     居家生活 其他 其他居家生活
# 12  4.4   56   300   13   服飾婦幼 女性內睡衣 其他內睡衣
# 13  4.7   52   413   33      服飾婦幼 男鞋男襪 馬汀靴
# 14  4.5   33   335   14     服飾婦幼 男性下身 工作短褲
# 15  4.7   33   259   12    服飾婦幼 女性下身 女休閒長褲
# 16  4.6   55   275   15     服飾婦幼 女性下身 牛仔長褲
# 17  4.7   59   256   11       服飾婦幼 男性內著 內褲
# 18  4.3   32   308   10      服飾婦幼 男性下身 西裝褲
# 19  4.5   20   200    7      服飾婦幼 男性下身 工作褲
# 20  4.6   33   235   10     服飾婦幼 男性下身 工作短褲
# 21  4.7   55   315    5       服飾婦幼 男性內著 內褲
# 22  4.5   91   605    9         服飾婦幼 男包 長夾
# 23  4.6   58   354   10         服飾婦幼 男包 長夾
# 24  4.4   28   185   12     戶外休閒 戶外用品 水上活動
# 25  4.5   53   191   14   服飾婦幼 男性下身 其他男性下身
# 26  4.4   22   283    5     服飾婦幼 女性上衣 長袖帽T
# 27  4.9   14   121    5      服飾婦幼 男性下身 工作褲
# 28  4.3   41   377    6    服飾婦幼 女包 零錢包&鑰匙包
# 29  4.6   17   239    9    服飾婦幼 女性下身 女休閒長褲
# 30  4.6   46   169    6       服飾婦幼 女鞋女襪 短襪
# 31  4.5   49   336    5   服飾婦幼 男性配飾 其他男性配飾
# 32  4.8   23    77    1       服飾婦幼 男性內著 內褲
# 33  4.4   19    91    6      服飾婦幼 男性下身 工作褲
# 34  4.9   12    46            服飾婦幼 男性內著 內褲
# 35  4.7   11    77    1       服飾婦幼 男性內著 內褲
# 36  4.6   22    93   19      服飾婦幼 男性下身 工作褲
# 37  4.4   20   200   12     服飾婦幼 女性上衣 長袖襯衫
