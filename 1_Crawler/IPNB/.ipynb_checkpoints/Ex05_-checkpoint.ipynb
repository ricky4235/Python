# %% [markdown]
# PTT web版的html結構算是比較有規則的, 所以也是拿來練爬蟲的好對象, 下面這隻爬蟲的目的是要去找出今日的熱門文章(50推以上), 同時也會去找出今天有哪些5566發文了:

# %%
import requests
import time
import json
from bs4 import BeautifulSoup


PTT_URL = 'https://www.ptt.cc'


def get_web_page(url):
    resp = requests.get(url=url, cookies={'over18': '1'})
    if resp.status_code != 200:
        print('Invalid url:', resp.url)
        return None
    else:
        return resp.text


def get_articles(dom, date):
    soup = BeautifulSoup(dom, 'html5lib')
    # Retrieve the link of previous page
    paging_div = soup.find('div', 'btn-group btn-group-paging')
    prev_url = paging_div.find_all('a')[1]['href']

    articles = []
    divs = soup.find_all('div', 'r-ent')
    for d in divs:
        # If post date matched:
        if d.find('div', 'date').text.strip() == date:
            # To retrieve the push count:
            push_count = 0
            push_str = d.find('div', 'nrec').text
            if push_str:
                try:
                    push_count = int(push_str)
                except ValueError:
                    # If transform failed, it might be '爆', 'X1', 'X2', etc.
                    if push_str == '爆':
                        push_count = 99
                    elif push_str.startswith('X'):
                        push_count = -10

            # To retrieve title and href of the article:
            if d.find('a'):
                href = d.find('a')['href']
                title = d.find('a').text
                author = d.find('div', 'author').text if d.find('div', 'author') else ''
                articles.append({
                    'title': title,
                    'href': href,
                    'push_count': push_count,
                    'author': author
                })

    return articles, prev_url


def get_author_ids(posts, pattern):
    ids = set()
    for post in posts:
        if pattern in post['author']:
            ids.add(post['author'])
    return ids


def main():
    current_page = get_web_page(PTT_URL + '/bbs/Gossiping/index.html')
    if current_page:
        # To keep all of today's articles.
        articles = []
        # Today's date, here we remove the 0 at the head to match the format of PTT date.
        # API doc for strftime: https://docs.python.org/3/library/datetime.html#strftime-strptime-behavior
        # API doc for lstrip: https://www.tutorialspoint.com/python/string_lstrip.htm
        today = time.strftime("%m/%d").lstrip('0')
        current_articles, prev_url = get_articles(current_page, today)

        while current_articles:
            articles += current_articles
            current_page = get_web_page(PTT_URL + prev_url)
            current_articles, prev_url = get_articles(current_page, today)

        print("Today's 5566:")
        print(get_author_ids(articles, '5566'))

        print('\nThere are ', len(articles), ' posts today.')
        threshold = 50
        print('Hot post(≥ %d push): ' % threshold)
        for article in articles:
            if int(article['push_count']) > threshold:
                print(article)
        # with as: https://openhome.cc/Gossip/Python/WithAs.html
        # json.dump: http://python3-cookbook.readthedocs.io/zh_CN/latest/c06/p02_read-write_json_data.html
        with open('gossiping.json', 'w', encoding='UTF-8') as file:
            json.dump(articles, file, indent=2, sort_keys=True, ensure_ascii=False)


if __name__ == '__main__':
    main()
# Out:
# Today's 5566:
# {'Loveis5566', 'FL5566', 'gangster5566', 'XDDDpupu5566', 'dumbo5566', 'Rin5566', 'lianpig5566', 'Tiara5566', 'kasumi5566', 'flameon5566', 'nanco5566', 'nikubou5566', 'casco5566', 'BaGaJohn5566', 'thor5566', 'aynmeow5566', 'kober5566', 'Blacky5566', 'odd5566', 'nail5566', 'kameaki5566', 'zrct5566', 'aass5566', 'Lime5566', 'aska5566', 'maochong5566', 'TomFord5566', 'Kyle5566', 'hk5566', 'Ommmmmm5566', 'KTR5566', 'Shiau5566', 'gy5566gy', 'LOLI5566', 'BlackDog5566', 'oz5566', 'ellis5566', 'BaoLiao5566', 'humor5566'}
#
# There are  1965  posts today.
# Hot post(≥ 50 push):
# {'title': 'Fw: [新聞] 韓國光州醫院封閉 121名醫護關在其中', 'href': '/bbs/Gossiping/M.1580981999.A.664.html', 'push_count': 72, 'author': 'jimmylily'}
# {'title': '[問卦] 遇到貓貓攔截怎麼辦', 'href': '/bbs/Gossiping/M.1580981198.A.89D.html', 'push_count': 64, 'author': 'DevilHotel'}
# {'title': '[爆卦] 韓國逾口罩限制出口', 'href': '/bbs/Gossiping/M.1580981363.A.0F1.html', 'push_count': 70, 'author': 'denst'}
# {'title': '[新聞] 俄13歲小妹「肚皮莫名隆起」老媽逼驗孕\u3000', 'href': '/bbs/Gossiping/M.1580980880.A.CD9.html', 'push_count': 73, 'author': 'lovea'}
# {'title': '[問卦] 口罩還可以發起什麼活動???', 'href': '/bbs/Gossiping/M.1580979717.A.F4D.html', 'push_count': 80, 'author': 'febula'}
# {'title': 'Re: [新聞] 陳時中：日產千萬片口罩難度高 實名制週', 'href': '/bbs/Gossiping/M.1580979354.A.DA9.html', 'push_count': 99, 'author': 'yam193431'}
# {'title': '[爆卦] 義大利米蘭火車翻車 至少2死', 'href': '/bbs/Gossiping/M.1580978702.A.020.html', 'push_count': 78, 'author': 'cycling'}
# {'title': '[新聞] 中央擬在宜蘭員山設隔離所 地方事前不知強烈反彈', 'href': '/bbs/Gossiping/M.1580978060.A.173.html', 'push_count': 62, 'author': 'colorless'}
# {'title': '[問卦] 被同事領口罩調查怎麼辦？', 'href': '/bbs/Gossiping/M.1580978344.A.010.html', 'push_count': 99, 'author': 'teemo0330'}
# {'title': '[新聞] 遼寧、江西宣布「封省」！', 'href': '/bbs/Gossiping/M.1580977667.A.D7D.html', 'push_count': 99, 'author': 'biostar'}
# {'title': '[新聞] 「沒有人願意生病！我打破了０」\u3000首例女', 'href': '/bbs/Gossiping/M.1580976900.A.B5D.html', 'push_count': 99, 'author': 'luxuryer'}
# {'title': '[爆卦] 中國外交部回應斷航：無助防疫 製造恐慌', 'href': '/bbs/Gossiping/M.1580976167.A.733.html', 'push_count': 99, 'author': 'newpasta'}
# {'title': '[新聞] 口罩實名制首日售出95萬片  克服瞬間爆量', 'href': '/bbs/Gossiping/M.1580975644.A.ECA.html', 'push_count': 64, 'author': 'kuro'}
# {'title': '[新聞] 讓醫護全心投入防疫！\u3000指揮官陳時中宣', 'href': '/bbs/Gossiping/M.1580975499.A.CA5.html', 'push_count': 94, 'author': 'br06'}
# {'title': '[問卦] 台灣人為什麼平常家裡會沒口罩', 'href': '/bbs/Gossiping/M.1580974723.A.907.html', 'push_count': 51, 'author': 'ig49999'}
# {'title': 'Re: [新聞] 中國包機竟偷渡非台人！柯文哲嘆：兩岸要', 'href': '/bbs/Gossiping/M.1580974062.A.F2E.html', 'push_count': 99, 'author': 'NARUTO'}
# {'title': '[新聞] 武漢肺炎酒精搶光！台酒湧搶買人潮\u3000指揮', 'href': '/bbs/Gossiping/M.1580973405.A.19C.html', 'push_count': 65, 'author': 'befly10015'}
# {'title': '[爆卦] 方艙醫院現況', 'href': '/bbs/Gossiping/M.1580972927.A.D86.html', 'push_count': 99, 'author': 'asya116'}
# {'title': '[爆卦] 火神山醫院招募清潔工', 'href': '/bbs/Gossiping/M.1580972987.A.9F2.html', 'push_count': 99, 'author': 'nomorepipe'}
# {'title': '[新聞] 史上最尷尬67秒！台南騎士揍人搶手機\u3000', 'href': '/bbs/Gossiping/M.1580972332.A.BAC.html', 'push_count': 99, 'author': 'sky419012'}
# {'title': '[問卦] 歷史上有名的內奸?', 'href': '/bbs/Gossiping/M.1580971533.A.E57.html', 'push_count': 53, 'author': 'bengowa'}
# {'title': '[新聞] 先安定疫情\u3000陳時中：今年醫院評鑑暫停', 'href': '/bbs/Gossiping/M.1580971686.A.581.html', 'push_count': 99, 'author': 'pasionlove'}
# {'title': '[新聞]日本急滅火 安倍： 今夏東奧不受武漢肺炎', 'href': '/bbs/Gossiping/M.1580971258.A.D6B.html', 'push_count': 99, 'author': 'poweroflove'}
# {'title': '[新聞] 血友病患滯留中國！身上藥物不夠用…四', 'href': '/bbs/Gossiping/M.1580970271.A.BFB.html', 'push_count': 87, 'author': 'powyo'}
# {'title': '[新聞] 台首例武漢病毒確診個案出院 手寫信表感', 'href': '/bbs/Gossiping/M.1580970341.A.DC0.html', 'push_count': 99, 'author': 'asuka99'}
# {'title': '[問卦] 鑽石公主號比偷渡中配事件嚴重多了吧？', 'href': '/bbs/Gossiping/M.1580970636.A.F9F.html', 'push_count': 98, 'author': 'PasManquer'}
# {'title': '[新聞] 豪放女高中生摩鐵玩3P 男友情人節收激戰', 'href': '/bbs/Gossiping/M.1580969777.A.F63.html', 'push_count': 61, 'author': 'RRADA'}
# {'title': '[新聞] 快訊／台灣再確認２例武漢肺炎！確診來到', 'href': '/bbs/Gossiping/M.1580969988.A.84D.html', 'push_count': 69, 'author': 'Moogle'}
# {'title': '[爆卦] 居住於中國大陸、香港、澳門的外籍人士，暫緩入境', 'href': '/bbs/Gossiping/M.1580969103.A.404.html', 'push_count': 99, 'author': 'eddie1209'}
# {'title': '[爆卦] 新增2例境外移入病例，全國共13例', 'href': '/bbs/Gossiping/M.1580969248.A.91C.html', 'push_count': 99, 'author': 'nomorepipe'}
# {'title': '[爆卦]  武漢市逐戶量體溫', 'href': '/bbs/Gossiping/M.1580969360.A.CE0.html', 'push_count': 99, 'author': 'Redart'}
# {'title': '[新聞] 密克羅尼西亞指定日本為「感染國」 限制入境', 'href': '/bbs/Gossiping/M.1580969365.A.FEF.html', 'push_count': 79, 'author': 'pshuang'}
# {'title': '[爆卦] 國內首例確診患者已痊癒將出院 向防疫及', 'href': '/bbs/Gossiping/M.1580969486.A.AA4.html', 'push_count': 99, 'author': 'xamous'}
# {'title': '[新聞] 中國：14日調降對美2.2兆元商品加徵關稅', 'href': '/bbs/Gossiping/M.1580968847.A.485.html', 'push_count': 79, 'author': 'semih'}
# {'title': '[新聞] 獨／國際郵輪禁靠港 寶瓶星號上千台人明', 'href': '/bbs/Gossiping/M.1580968847.A.E51.html', 'push_count': 93, 'author': 'kevinlee2001'}
# {'title': '[新聞] 快訊／徐正文領表參選中常委\u3000同一時間.', 'href': '/bbs/Gossiping/M.1580967830.A.C17.html', 'push_count': 97, 'author': 'Y225'}
# {'title': '[新聞] 小學老師要揍人！全班40學生嚇得急衝出', 'href': '/bbs/Gossiping/M.1580968190.A.82B.html', 'push_count': 84, 'author': 'codechem'}
# {'title': '[爆卦] 日本政府：隔離從10天改成12.5天', 'href': '/bbs/Gossiping/M.1580967654.A.076.html', 'push_count': 99, 'author': 'digimongo'}
# {'title': 'Re: [新聞] 絕交！川普發表完國情咨文波洛西當場撕掉', 'href': '/bbs/Gossiping/M.1580966996.A.17E.html', 'push_count': 99, 'author': 'Beisbol'}
# {'title': '[新聞] 30歲辣模產下豪門金孫 「母憑子貴」19億', 'href': '/bbs/Gossiping/M.1580967122.A.923.html', 'push_count': 51, 'author': 'XXXXCOW'}
# {'title': '[新聞] 解釋糞口傳播 女官員：就是吃了別人的屎', 'href': '/bbs/Gossiping/M.1580966517.A.73E.html', 'push_count': 99, 'author': 'waymayday'}
# {'title': '[新聞] 桃園再爆3居家隔離者到處亂跑 男「帶女', 'href': '/bbs/Gossiping/M.1580966243.A.CAB.html', 'push_count': 92, 'author': 'centre0130'}
# {'title': '[新聞] 18年來第一次！胡瓜《大集合》防疫處置「', 'href': '/bbs/Gossiping/M.1580965603.A.39F.html', 'push_count': 95, 'author': 'richshen'}
# {'title': '[問卦] 中國醫療是不是廢到讓人笑', 'href': '/bbs/Gossiping/M.1580965667.A.A86.html', 'push_count': 99, 'author': 'onion27'}
# {'title': '[問卦] 郵輪到公海 病例算誰的', 'href': '/bbs/Gossiping/M.1580965009.A.4C3.html', 'push_count': 68, 'author': 'ckk007'}
# {'title': '[問卦] 俊美鳳梨酥是台灣第一強嗎?', 'href': '/bbs/Gossiping/M.1580964574.A.94F.html', 'push_count': 70, 'author': 'ThorFukt'}
# {'title': '[新聞] 知名網紅評比「品質不佳」 佳德鳳梨酥開', 'href': '/bbs/Gossiping/M.1580963775.A.9A5.html', 'push_count': 99, 'author': 'seysem'}
# {'title': '[問卦] 政府如果要「強制隔離」地址選哪最好?', 'href': '/bbs/Gossiping/M.1580963272.A.992.html', 'push_count': 95, 'author': 'safefree'}
# {'title': '[新聞] 武漢肺炎患者1天改善！\u3000台灣女科學家楊', 'href': '/bbs/Gossiping/M.1580963428.A.DD2.html', 'push_count': 99, 'author': 'sinana'}
# {'title': '[問卦] 包機抵達後 名單不對的人為何不能遣返', 'href': '/bbs/Gossiping/M.1580963004.A.7BB.html', 'push_count': 53, 'author': 'JimJackson'}
# {'title': '[新聞] 沒帶口罩！杭州男到藥局領藥...「50秒面', 'href': '/bbs/Gossiping/M.1580962325.A.4EC.html', 'push_count': 55, 'author': 'Rambo'}
# {'title': '[新聞] 專機撤台惹議 柯:搞一次後大家沒信任更慘', 'href': '/bbs/Gossiping/M.1580962480.A.604.html', 'push_count': 97, 'author': 'ctw01'}
# {'title': '[新聞] 林右昌曝基隆往後五天是關鍵 港務分公司歸交通部管轄', 'href': '/bbs/Gossiping/M.1580962127.A.405.html', 'push_count': 96, 'author': 'allgamba'}
# {'title': '[新聞] 中國隱匿疫情？譚德塞：現在不能說有或沒', 'href': '/bbs/Gossiping/M.1580962196.A.BAB.html', 'push_count': 99, 'author': 'drea'}
# {'title': '[爆卦] 杭州市建議民眾喝酒防疫', 'href': '/bbs/Gossiping/M.1580961306.A.487.html', 'push_count': 66, 'author': 'KAKAii'}
# {'title': '[問卦]有沒有 我的便當裡面被下了什麼藥的掛？', 'href': '/bbs/Gossiping/M.1580961425.A.F2A.html', 'push_count': 85, 'author': 'Archerdark'}
# {'title': '[爆卦] 瑞德西韋被搶專利的吉利德公司CEO回應了！', 'href': '/bbs/Gossiping/M.1580961200.A.8D5.html', 'push_count': 99, 'author': 'Dean1116'}
# {'title': '[問卦] 這時間又去大陸的台人該怎辦', 'href': '/bbs/Gossiping/M.1580960767.A.2F1.html', 'push_count': 85, 'author': 'SM19'}
# {'title': '[新聞] 「武漢台商包機完全走樣！」蘇貞昌怒轟', 'href': '/bbs/Gossiping/M.1580960237.A.C8F.html', 'push_count': 99, 'author': 'Wojnarowski'}
# {'title': '[新聞] 藍委喊話「讓里長發口罩」\u3000謝震武突破', 'href': '/bbs/Gossiping/M.1580960467.A.985.html', 'push_count': 65, 'author': 'tang639'}
# {'title': '[爆卦] 二月六日開始國際郵輪禁止靠岸台灣', 'href': '/bbs/Gossiping/M.1580960491.A.358.html', 'push_count': 99, 'author': 'ctes940008'}
# {'title': 'Re: [爆卦] 鑽石公主號出現台灣人感染者了', 'href': '/bbs/Gossiping/M.1580958736.A.C4E.html', 'push_count': 77, 'author': 'allgamba'}
# {'title': 'Re: [新聞] 一改嗆聲態度 柯文哲：我對台灣防疫有信', 'href': '/bbs/Gossiping/M.1580958424.A.AF0.html', 'push_count': 52, 'author': 'Tiphareth'}
# {'title': '[新聞] 「口罩實名制」今上路 柯P：有需要才買', 'href': '/bbs/Gossiping/M.1580958667.A.654.html', 'push_count': 99, 'author': 'xamous'}
# {'title': 'Re: [新聞] 不需要一直戴口罩\u3000林楚茵：柯文哲、韓國', 'href': '/bbs/Gossiping/M.1580958046.A.874.html', 'push_count': 99, 'author': 'deann'}
# {'title': '[新聞] 罷韓連署書郵件遭攔截？韓粉郵務士「黃亦新」臉書自揭犯行', 'href': '/bbs/Gossiping/M.1580957097.A.E5B.html', 'push_count': 98, 'author': 'blueadam193'}
# {'title': '[問卦] 男友跟男生天天上健身房我該注意什麼', 'href': '/bbs/Gossiping/M.1580956547.A.2C6.html', 'push_count': 57, 'author': 'chenging'}
# {'title': 'Re: [新聞] 不需要一直戴口罩\u3000林楚茵：柯文哲、韓國', 'href': '/bbs/Gossiping/M.1580956120.A.BCF.html', 'push_count': 99, 'author': 'yida0725'}
# {'title': '[新聞] 陳時中原年後轉政委 疫情來服喪領導抗疫', 'href': '/bbs/Gossiping/M.1580955146.A.5C8.html', 'push_count': 78, 'author': 'xFANx'}
# {'title': '[新聞] 解放軍、武警被爆疫情嚴重', 'href': '/bbs/Gossiping/M.1580954738.A.FA8.html', 'push_count': 99, 'author': 'IN'}
# {'title': '[新聞] 日本專家：新病毒不可怕,流感措施即可', 'href': '/bbs/Gossiping/M.1580954391.A.81C.html', 'push_count': 99, 'author': 'jin168chen'}
# {'title': '[新聞] 武漢肺炎》 「我拿到了！」全店歡呼 民', 'href': '/bbs/Gossiping/M.1580954256.A.0C8.html', 'push_count': 99, 'author': 'lpbrother'}
# {'title': '[新聞] 鑽石公主號再增10確診 包括1名台灣人', 'href': '/bbs/Gossiping/M.1580953635.A.083.html', 'push_count': 57, 'author': 'udism'}
# {'title': '[爆卦] 武漢肺炎上海死亡者復活', 'href': '/bbs/Gossiping/M.1580953724.A.DFC.html', 'push_count': 99, 'author': 'xiemark'}
# {'title': '[問卦] 台灣是不是全世界最懂支那的國家', 'href': '/bbs/Gossiping/M.1580953796.A.138.html', 'push_count': 68, 'author': 'monocyte123'}
# {'title': '[爆卦] 邱顯智 使非法入境可處一年以上七年以下', 'href': '/bbs/Gossiping/M.1580952914.A.A71.html', 'push_count': 99, 'author': 'jk808631'}
# {'title': '[新聞] 徐正文拿機位做人情？網：你會下地獄！', 'href': '/bbs/Gossiping/M.1580952139.A.D09.html', 'push_count': 99, 'author': 'moneybuy'}
# {'title': '[問卦] 不在入境許可名單不能遣返嗎', 'href': '/bbs/Gossiping/M.1580951459.A.06E.html', 'push_count': 51, 'author': 'ElectronPair'}
# {'title': '[新聞] 「鑽石公主號」確診武漢肺炎累計達20例', 'href': '/bbs/Gossiping/M.1580950786.A.A77.html', 'push_count': 99, 'author': 'Salcea'}
# {'title': '[問卦] 口罩依然在排隊', 'href': '/bbs/Gossiping/M.1580951137.A.6A0.html', 'push_count': 75, 'author': 'Kootinlok'}
# {'title': '[新聞] 砲轟徐正文未獲授權！武漢同鄉會長打臉', 'href': '/bbs/Gossiping/M.1580950365.A.20C.html', 'push_count': 56, 'author': 'Luckmeow'}
# {'title': 'Re: [新聞]外銷「工業口罩」卡關\u3000海外客戶賠償', 'href': '/bbs/Gossiping/M.1580950011.A.BD6.html', 'push_count': 99, 'author': 'markkao456'}
# {'title': '[爆卦] 網內互打開始了', 'href': '/bbs/Gossiping/M.1580948181.A.AE0.html', 'push_count': 99, 'author': 'asya116'}
# {'title': '[爆卦] 雲南大理市徵用了寄往重慶市的口罩', 'href': '/bbs/Gossiping/M.1580948601.A.790.html', 'push_count': 99, 'author': 'derekhsu'}
# {'title': '[爆卦] 日本 追加10人新型肺炎陽性反應 目前45人', 'href': '/bbs/Gossiping/M.1580947481.A.73F.html', 'push_count': 99, 'author': 'devilclot'}
# {'title': '[新聞] 泰國宣布「列管」口罩 由政府控制出口量', 'href': '/bbs/Gossiping/M.1580946385.A.400.html', 'push_count': 99, 'author': 'wwf0322'}
# {'title': '[爆卦] 橫濱 公主郵輪新增十人?!', 'href': '/bbs/Gossiping/M.1580946495.A.9C1.html', 'push_count': 67, 'author': 'thepowers'}
# {'title': 'Re: [新聞] 化解蔡英文窘境！國民黨7人小組出手\u3000促', 'href': '/bbs/Gossiping/M.1580947139.A.6AA.html', 'push_count': 99, 'author': 'IL12'}
# {'title': '[問卦] 中配1毛稅都沒繳,卻優先台灣人爽搭飛機??', 'href': '/bbs/Gossiping/M.1580945090.A.A18.html', 'push_count': 99, 'author': 'Whitening'}
# {'title': '[問卦] 是不是不管怎樣政府都要背這個鍋？', 'href': '/bbs/Gossiping/M.1580945936.A.A33.html', 'push_count': 99, 'author': 'jokebbs'}
# {'title': '[問卦] 打電話到自己區域立委施壓吧', 'href': '/bbs/Gossiping/M.1580942217.A.521.html', 'push_count': 99, 'author': 'dumbo5566'}
# {'title': '[爆卦] 支那肺炎 死亡562 確診27447 死亡率維持2%', 'href': '/bbs/Gossiping/M.1580942648.A.6B9.html', 'push_count': 99, 'author': 'b1b2b3b4'}
# {'title': 'Re: [爆卦] 第一批撤僑50多個非台灣人', 'href': '/bbs/Gossiping/M.1580943129.A.23F.html', 'push_count': 97, 'author': 'jackhsu1'}
# {'title': '[問卦] 那個確診的 是不是大陸故意塞的？', 'href': '/bbs/Gossiping/M.1580944598.A.57F.html', 'push_count': 92, 'author': 'BIA'}
# {'title': '[問卦] 誰安排徐正文當居中人？', 'href': '/bbs/Gossiping/M.1580939752.A.14D.html', 'push_count': 54, 'author': 'MadCaro'}
# {'title': 'Re: [問卦] 武漢肺炎也會數學？', 'href': '/bbs/Gossiping/M.1580941400.A.B3E.html', 'push_count': 99, 'author': 'hugoyo'}
# {'title': '[問卦] 幫徐正文說一句話就好......', 'href': '/bbs/Gossiping/M.1580936371.A.B49.html', 'push_count': 99, 'author': 'wade8204'}
# {'title': 'Re: [問卦] 如果第二批又偷渡中國籍的進來怎麼辦?', 'href': '/bbs/Gossiping/M.1580932254.A.C42.html', 'push_count': 52, 'author': 'demitri'}
# {'title': '[問卦] 如果第二批又偷渡中國籍的進來怎麼辦?', 'href': '/bbs/Gossiping/M.1580931280.A.753.html', 'push_count': 80, 'author': 'spirit119'}
# {'title': '[爆卦] 藥局口罩採購地圖上線', 'href': '/bbs/Gossiping/M.1580927736.A.58E.html', 'push_count': 79, 'author': 'olctw'}
# {'title': 'Re: [問卦] 混怒到睡不著怎麼辦？', 'href': '/bbs/Gossiping/M.1580926601.A.5B5.html', 'push_count': 99, 'author': 'bakapika'}
# {'title': '[爆卦] 徐正文為什麼該被吊在路燈上', 'href': '/bbs/Gossiping/M.1580927001.A.3DE.html', 'push_count': 99, 'author': 'lilavadee'}
# {'title': '[新聞] 「病毒旗」漫畫家 收到數百條氣噗噗的留言', 'href': '/bbs/Gossiping/M.1580927227.A.02D.html', 'push_count': 75, 'author': 'rutw'}
# {'title': '[問卦] 台灣跟中國完全沒交流活的下去嗎', 'href': '/bbs/Gossiping/M.1580925417.A.7BF.html', 'push_count': 58, 'author': 'jerry0604321'}
# {'title': '[問卦] 無力感是不是很重？', 'href': '/bbs/Gossiping/M.1580925815.A.D0A.html', 'push_count': 51, 'author': 'hoothom'}
# {'title': '[問卦] 徐正文vs.黃安誰比較討厭？', 'href': '/bbs/Gossiping/M.1580925234.A.636.html', 'push_count': 99, 'author': 'yaotz5065'}
# {'title': '[新聞] 怒飆徐正文噁心 王世堅：哭給你祖公聽', 'href': '/bbs/Gossiping/M.1580924038.A.F8A.html', 'push_count': 99, 'author': 'hk5566'}
# {'title': '[爆卦] 徐正文是北京政協、念"習近平談治國理政"', 'href': '/bbs/Gossiping/M.1580924059.A.A15.html', 'push_count': 99, 'author': 'DreamYeh'}
# {'title': '[問卦] 所以那五十位要怎摸處理', 'href': '/bbs/Gossiping/M.1580923083.A.B1F.html', 'push_count': 99, 'author': 'iecju520'}
# {'title': '[問卦] 有徐正文人被凌遲而死的八卦嗎？', 'href': '/bbs/Gossiping/M.1580923179.A.088.html', 'push_count': 89, 'author': 'dans'}
# {'title': 'Re: [問卦] 徐正文真的無法可管嗎= =', 'href': '/bbs/Gossiping/M.1580922730.A.577.html', 'push_count': 99, 'author': 'diofishfish'}
# {'title': 'Re: [問卦] 特約藥局買口罩，該怎麼找？', 'href': '/bbs/Gossiping/M.1580922507.A.A9D.html', 'push_count': 99, 'author': 'hank85627'}
# {'title': '[問卦] 登入1500天啦！', 'href': '/bbs/Gossiping/M.1580921974.A.7D1.html', 'push_count': 99, 'author': 'tomioki'}
# {'title': '[問卦] 笨蛋，問題不是在陸配', 'href': '/bbs/Gossiping/M.1580921578.A.634.html', 'push_count': 51, 'author': 'mOoOm'}
# {'title': '[問卦] 再重來一次，你各位會同意包機撤離嗎？', 'href': '/bbs/Gossiping/M.1580921595.A.E96.html', 'push_count': 53, 'author': 'zx821027'}
# {'title': '[問卦] 人要多無恥才能向徐正文一樣噁心', 'href': '/bbs/Gossiping/M.1580921306.A.785.html', 'push_count': 96, 'author': 'p6011150111'}
# {'title': '[問卦] 徐正文真的無法可管嗎= =', 'href': '/bbs/Gossiping/M.1580921110.A.725.html', 'push_count': 99, 'author': 'NukAnah'}
# {'title': '[問卦] 武漢是不是失火了？', 'href': '/bbs/Gossiping/M.1580920712.A.577.html', 'push_count': 90, 'author': 'jimmylily'}
# {'title': '[問卦] 真的很氣 八卦都綠爆了', 'href': '/bbs/Gossiping/M.1580920383.A.F72.html', 'push_count': 99, 'author': 'k960608'}
# {'title': 'Re: [問卦] 幫徐正文說兩句話……', 'href': '/bbs/Gossiping/M.1580920434.A.707.html', 'push_count': 75, 'author': 'love5656'}
# {'title': '[問卦] 到底多冷血才會去打壓可憐的血友病患者？', 'href': '/bbs/Gossiping/M.1580919169.A.F57.html', 'push_count': 59, 'author': 'chungrew'}
# {'title': '[新聞] 口罩、防護衣被中國整廠包走 南六董座', 'href': '/bbs/Gossiping/M.1580919297.A.40C.html', 'push_count': 99, 'author': 'helikon'}
# {'title': '[問卦] 552萬人經過這次事件會醒過來嗎?', 'href': '/bbs/Gossiping/M.1580918938.A.2A5.html', 'push_count': 99, 'author': 'PPPa'}
# {'title': '[爆卦] 土耳其伊斯坦堡飛機衝出跑道斷兩截', 'href': '/bbs/Gossiping/M.1580919003.A.5D4.html', 'push_count': 86, 'author': 'f544544f'}
