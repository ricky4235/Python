# %% [markdown]
# # 蘋果日報今日焦點

# %%
import requests
from bs4 import BeautifulSoup


APPLE_DAILY_HEADLINE = 'http://www.appledaily.com.tw/appledaily/hotdaily/headline'
LTN_NEWS = 'https://news.ltn.com.tw/'


def main():
    print('蘋果今日焦點')
    resp = requests.get(APPLE_DAILY_HEADLINE).text
    soup = BeautifulSoup(resp, 'html5lib')
    for headline in soup.find('ul', 'all').find_all('li'):
        print(
            headline.find('div', 'aht_title_num').text, 
            #前十大新聞標籤的class為"aht_title_num atopred"，20~30為"aht_title_num"
            #用前者的話，到第11項會出現AttributeError: 'NoneType' object has no attribute 'text'
            #用後者的話都跑的出來，表示只要前面一樣就好，後面有空白的話，空白之後的省略也可
            headline.find('div', 'aht_title').text,
            headline.find('div', 'aht_title_pv').text
        )
    print('---------')
    print('自由今日焦點')
    resp = requests.get(LTN_NEWS).text
    soup = BeautifulSoup(resp, 'html5lib')
    for lte_news in soup.find('ul','list').find_all('li'):
        print(lte_news.find('span', 'title').text)


if __name__ == '__main__':
    main()
# Out:
# 蘋果今日焦點
# 01 最巨大的力量 不是病毒是文字！
#
#
#
# 02 日專家登船：比伊波拉慘
#
#
#
# 03 南韓「毒后」上教會 1傳15 發燒在首爾大邱趴趴走 害166人須隔離
#
#
#
# 04 見證下冊封的“愛新覺羅毓昊博士”
#
#
#
# 05 劉真 心臟手術遇難關 葉克膜搶救集氣續命
#
#
#
# 06 2年未出國 北部爆退休婦確診 流感住院19天才轉負壓房 接觸360人將採檢
#
#
#
# 07 辛龍 娶劉真中樂透1.2億 4歲女等媽媽醒來
#
#
#
# 08 高規格防疫 明專機接疫輪19台人 全程穿隔離衣 1人坐1排 不供餐只供尿布
#
#
#
# 09 興富發標下達新7期廠地 豪擲83.47億元 創台中史上最高總價
#
#
#
# 10 葉克膜維生 救回胡志強妻
#
#
#
# 11 被詐200萬 假扮女網友瞎掰訊息肉搜幕後黑手 誆武漢偷渡回台 男遭移送
#
#
#
# 12 當人形病毒隔離 清大女孤夜痛哭
#
#
#
# 13 國標女王 對美有執念 鞋痴收藏近千雙
#
#
#
# 14 不准爬升 F-16撞山 5失職軍官遭彈劾
#
#
#
# 15 《蘋果開箱》搶先實測 輕薄三防手機S52 防摔效果好 直接水洗防武漢肺炎
#
#
#
# 16 黃倩萍 怒駁和小鮮肉上摩鐵 認離婚3年單身ing
#
#
#
# 17 網購外送乘勢而起 電商出頭天
#
#
#
# 18 武漢遭疫情肆虐 竟轉售口罩物資
#
#
#
# 19 東出昌大 偷腥掃到長澤雅美 悔「已失去一切」
#
#
#
# 20 蘋論：國民黨的兩大燙手山芋
#
#
#
# 21 阿雅遭空姊趕下機 多燒10萬當改運
#
#
#
# 22 蘋中信：卸任元首，是在哈佛？（苗博雅）
#
#
#
# 23 楊麗菁憂心號哭 「約好當20年閨蜜」
#
#
#
# 24 小S祈福「好起來」 吳宗憲持續關心
#
#
#
# 25 4000校 開學前須消毒完成 學童發燒在家不列缺勤 畢旅前須健康篩檢
#
#
#
# 26 抗疫期 飯店改裝提早開跑 住房促銷+設備升級  化危機拼轉機
#
#
#
# 27 不能寫負面新聞記者嘆「魔鬼的交易」
#
#
#
# 28 花縣收買15記者 3官遭懲 前副祕書長記過2次罰10萬 被減薪處長：我不是很高興
#
#
#
# 29 吳斯懷批蔡挑釁中國 林昶佐轟：說你舔共剛好
#
#
#
# 30 7天前曬手作巧克力 預祝情人節是代po
#
#
#
# ---------
# 自由今日焦點
# 武漢肺炎》首死感染源找到了！浙江台商血液驗出病毒抗體
# 《愛的迫降》世理和正赫的手錶 都出自這個品牌
# 武漢肺炎》治療藥物重大進展 國衛院完成「瑞德西韋」毫克級合成
# 1月外銷訂單大衰退  年減12.8％
# 國民黨團優先法案 聚焦紓困條例、18歲公民權
# 武漢肺炎》倫敦市長候選人「自薦」接手奧運！日網友崩潰
# 總統大選撕毀選票 屏東婦人遭罰2500元
# 防疫少出門！奇摩拍賣史上首次「無門檻」超取免運 不限金額、次數
# 1男1女登山失足卡崩壁 警消成功救援
# 開直播散佈「政府送50萬個口罩到香港」假訊息  無業男被辦
# 武漢肺炎》停課標準地方傳雜音 盧秀燕：跟中央同步
# 好萊塢女星為之瘋狂！「偽素顏裸妝」抓到這3個重點就完美了
# 京東遭指拖欠貨款逾14億！苦主揚言「欠債還錢，天經地義」
# 法操》【台灣法律史】臺灣的訓政經驗─黨治經驗
# 武漢肺炎疫情驅使 中國國債收益率降至4年新低
# 長輩一句話！黃子佼取消登記結婚   哀嘆：冥冥之中的力量
# 持續減持人民幣 國泰金：4成民眾預期人民幣將貶值逾2％
# 無偽裝測試車再度現身，Ford 小休旅更多細節公開！
# 「一秒噴2片」  口罩千萬產線力拚3月9號全開
# 武漢肺炎》爭取2月底控制疫情 中共智囊：否則很多企業都會倒閉

# %% [markdown]
# # ChinatimesNews_多線程(使用手機分享的網路再爬)
# https://tlyu0419.github.io/2019/10/30/%E5%A6%82%E4%BD%95%E9%80%8F%E9%81%8E%E7%B6%B2%E8%B7%AF%E7%88%AC%E8%9F%B2%E6%8A%93%E5%8F%96%E4%B8%AD%E6%99%82%E9%9B%BB%E5%AD%90%E5%A0%B1%E6%96%B0%E8%81%9E/#more

# %% [markdown]
# ### 載入使用套件

# %%
# !pip install tomorrow
# Out:
# Requirement already satisfied: tomorrow in c:\users\11004076\anaconda3\lib\site-packages (0.2.4)
# Requirement already satisfied: futures>=2.2.0 in c:\users\11004076\anaconda3\lib\site-packages (from tomorrow) (3.1.1)

# %%
# 爬蟲類套件
import requests
import json
from bs4 import BeautifulSoup
# 加入使用者資訊(如使用什麼瀏覽器、作業系統...等資訊)模擬真實瀏覽網頁的情況
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36'}
#from tomorrow import threads  #錯誤
# 資料整理類套件
import pandas as pd
import re
from datetime import datetime

# 其他
import os

# %% [markdown]
# ### 擷取一篇新聞

# %%
def GetNews_chinatimes(response):
    soup = BeautifulSoup(response.text)
    url = soup.find('link')['href']
    ndf = pd.DataFrame(data = [{'TITLE':soup.find('h1', attrs={'class':'article-title'}).text,
                                'TIME':datetime.strptime(soup.find('meta', attrs={'property':'article:published_time'})['content'],'%Y-%m-%dT%H:%M:%S+08:00'),
                                'CATEGORY':soup.find('meta',attrs={'property':'article:section'})['content'],
                                'DESCRIPTION':soup.find('meta',attrs={'name':'description'})['content'],
                                'CONTENT':'\n'.join(i.text for i in soup.find('div',attrs={'class':'article-body'}).find_all('p')),
                                'KEYWORDS':soup.find('meta',{'name':'news_keywords'})['content'],
                                'FROM':soup.find('meta',{'name':'publisher'})['content'],
                                'LINK':soup.find('meta', {'property':'og:url'})['content']}],
                       columns = ['TITLE', 'TIME', 'CATEGORY', 'DESCRIPTION', 'CONTENT','KEYWORDS', 'FROM', 'LINK']) 
    return ndf

# %%
url = 'https://www.chinatimes.com/newspapers/20191028000424-260118?chdtv'
resp = requests.get(url)
GetNews_chinatimes(resp)
# Out:
#                          TITLE                TIME CATEGORY  \
# 0  直球對決 韓接招青年辣提問！可以討厭我 但請聽我的政策 2019-10-28 04:10:19     政治要聞
#
#                                          DESCRIPTION  \
# 0  國民黨總統參選人韓國瑜昨晚在台北舉辦青年論壇，標榜「走出同溫層」，果然在場青年提問辛辣，毫不...
#
#                                              CONTENT        KEYWORDS   FROM  \
# 0  國民黨總統參選人韓國瑜昨晚在台北舉辦青年論壇，標榜「走出同溫層」，果然在場青年提問辛辣，毫不...  韓國瑜,國民黨,2020大選  中時電子報
#
#                                                 LINK
# 0  https://www.chinatimes.com/newspapers/20191028...

# %% [markdown]
# ### 擷取特定關鍵詞新聞的連結清單

# %%
def GetLinks_chinatimes(response):
    links = []
    soup = BeautifulSoup(response.text)
    for i in soup.find_all('h3'):
        url = i.find('a')['href']
        links.append(url)
    return links

# %%
url = 'https://www.chinatimes.com/search/英國'
resp = requests.get(url)
GetLinks_chinatimes(resp)
# Out:
# ['https://www.chinatimes.com/realtimenews/20200605002058-260410',
#  'https://www.chinatimes.com/realtimenews/20200605002246-260407',
#  'https://www.chinatimes.com/realtimenews/20200605002086-260407',
#  'https://www.chinatimes.com/fashion/20200605002249-263902',
#  'https://www.chinatimes.com/realtimenews/20200604002008-260409',
#  'https://www.chinatimes.com/realtimenews/20200604003095-260410',
#  'https://www.chinatimes.com/realtimenews/20200604001818-260410',
#  'https://www.chinatimes.com/realtimenews/20200604001789-260410',
#  'https://www.chinatimes.com/realtimenews/20200604006115-260402',
#  'https://www.chinatimes.com/realtimenews/20200604001834-260408',
#  'https://www.chinatimes.com/realtimenews/20200604001442-260410',
#  'https://www.chinatimes.com/realtimenews/20200604005647-260408',
#  'https://www.chinatimes.com/newspapers/20200604000227-260203',
#  'https://www.chinatimes.com/realtimenews/20200604005548-260402',
#  'https://www.chinatimes.com/realtimenews/20200604001271-260409',
#  'https://www.chinatimes.com/fashion/20200604001136-263901',
#  'https://www.chinatimes.com/realtimenews/20200603005857-260408',
#  'https://www.chinatimes.com/realtimenews/20200603005519-260407',
#  'https://www.chinatimes.com/realtimenews/20200603002069-260408',
#  'https://www.chinatimes.com/realtimenews/20200603002377-260409']

# %% [markdown]
# ### 開啟多線程功能
# * 只要組合以上兩個函數，其實就已經可以實現自動化的爬蟲作業了，具體方式其實就是逐一的把新聞連結清單放入 for 迴圈中，並透過 GetNews_chinatimes 函數解析新聞就可以了
# * 這樣m的方式在少量資料的時候還可以，但當我們需要抓上千、萬篇新聞時，「逐一」這件事請就顯得非常沒有效率。那有什麼辦法解決呢? 答案是我們可以運用多核心多線程的功能同時抓取多篇新聞內容，只需要運用 tomorrow 套件就能讓開啟多線程變得非常簡單，使用方式如下

# %% [markdown]
# 使用提醒：
#
# * threadms 數開得太高有可能會導致被網站封鎖 IP 而禁止連線。
# * 具體要設定多少 threads 數才不會被鎖?這需要慢慢嘗試過後能才知道，每個網站的反爬蟲機制不太一致。
# * 建議在抓資料時使用手機分享的網路，因為被封鎖 IP 狀況發生時只需要開啟飛航模式再關閉，就會替換成新 IP 而解除封鎖囉!

# %%
#@threads(100)
def MultiThread_Crawl(url):
    try:
        return requests.get(url, headers=headers)
    except:
        pass

# %% [markdown]
# ### 組合應用

# %%
def CrawlNews_chinatimes(keywords, pages):
    # 截取多個分頁的新聞連結
    links = []
    for i in range(pages):
        url = 'https://www.chinatimes.com/search/{}?page={}'.format(keywords, i+1)
        resp = requests.get(url)
        links += GetLinks_chinatimes(resp)   
    print('There are {} links in pages.'.format(len(links)))

    # 多線程爬蟲
    responses = [MultiThread_Crawl(link) for link in links]

    # 整理成DataFrame
    list_of_dataframes = []
    for response in responses:
        try:
            ndf = GetNews_chinatimes(response)
            list_of_dataframes.append(ndf)
        except:
            pass
    df = pd.concat(list_of_dataframes, ignore_index=True)
    print('There are {} News in DataFrame.'.format(len(df)))
    return df

# %%
# %%time
# 可以自行替換查詢的關鍵字，另外需要更多新聞的人也可以把 pages 的數值調高)
df = CrawlNews_chinatimes(keywords='美國', pages=10)
# Out:
# There are 200 links in pages.
# There are 200 News in DataFrame.
# Wall time: 21.3 s

# %%
df
# Out:
#                           TITLE                TIME CATEGORY  \
# 0        跟大陸握手言和？傳美國也讓步 准許陸客機飛美 2020-06-05 09:23:05       財經
# 1        直播》非裔遭白人警殺害 美國示威暴動最新現場 2020-06-05 08:07:02       國際
# 2        加拿大電信三大決定不用華為 美國還是要再補刀 2020-06-05 15:52:07       財經
# 3    工商社論》解封後的美國，一種民主，兩種社會，三種解讀 2020-06-05 04:10:00     工商社論
# 4              美傳將改變政策 准陸客運航班赴美 2020-06-05 11:30:32       財經
# ..                          ...                 ...      ...
# 195         對付燎原暴動 美為自己人出動了哪些武器 2020-06-03 17:51:18       軍事
# 196     美韓防衛費談判露曙光！4000無薪假雇員將復工 2020-06-03 09:46:24       軍事
# 197   弗洛伊德之死點燃種族歧視問題 艾倫狄珍妮絲心碎哭了 2020-06-03 13:13:03       娛樂
# 198               大陸建設 強攻高檔飯店住宅 2020-06-03 04:10:00    產業．科技
# 199           百年前染天花 鐵棺女屍容貌竟沒變！ 2020-06-03 21:20:55       社會
#
#                                            DESCRIPTION  \
# 0    美陸日前把戰火延伸到天空戰場，美國政府3日宣布，16日起將禁止大陸民航飛往美國。隔日，北京政...
# 1    美國非裔遭白警不當執法致死引起全國眾怒，示威遍布全美各大城市，至今已持續10天，雖然部分地區...
# 2    儘管加拿大電信三大公司：羅傑斯、貝爾公司、科研都已表態不會採用華為的5G設備，但美國仍不放心...
# 3    一位非洲裔民眾被執法的白人警察，以膝蓋壓制頸部在地，一直說他不能呼吸（I can't bre...
# 4    傳美國政府和航空公司官員於美東時間4日表示，美國運輸部計劃在未來幾天發布修改後的命令，可能會...
# ..                                                 ...
# 195  明尼亞波利斯白人警察因以膝蓋壓頸，導致非裔男子佛洛伊德（George Floyd）死亡，引燃...
# 196  美國國防部昨（2）日宣布，接受韓國的提議，一直至今年底，韓方將提供超過2億美元，資助4,00...
# 197  46歲非裔男子佛洛伊德（George Floyd）上月底在美國明尼蘇達州首府明尼亞波里斯市因...
# 198  大陸建設搶當「五星飯店住宅大亨」，大陸建設董事長張良吉2日表示，大陸建設要做的是創新、加值，...
# 199  2011年紐約建築工人，操作挖土機時，在工地中挖到一座鐵製棺材，打開後發現鐵棺裡有一具女屍，...
#
#                                                CONTENT  \
# 0    美陸日前把戰火延伸到天空戰場，美國政府3日宣布，16日起將禁止大陸民航飛往美國。隔日，北京政...
# 1    美國非裔遭白警不當執法致死引起全國眾怒，示威遍布全美各大城市，至今已持續10天，雖然部分地區...
# 2    儘管加拿大電信三大公司：羅傑斯、貝爾公司、科研都已表態不會採用華為的5G設備，但美國仍不放心...
# 3    一位非洲裔民眾被執法的白人警察，以膝蓋壓制頸部在地，一直說他不能呼吸（I can't bre...
# 4    傳美國政府和航空公司官員於美東時間4日表示，美國運輸部計劃在未來幾天發布修改後的命令，可能會...
# ..                                                 ...
# 195  明尼亞波利斯白人警察因以膝蓋壓頸，導致非裔男子佛洛伊德（George Floyd）死亡，引燃...
# 196  美國國防部昨（2）日宣布，接受韓國的提議，一直至今年底，韓方將提供超過2億美元，資助4,00...
# 197   Sign a petition. Make a donation. Get informe...
# 198  大陸建設搶當「五星飯店住宅大亨」，大陸建設董事長張良吉2日表示，大陸建設要做的是創新、加值，...
# 199  2011年紐約建築工人，操作挖土機時，在工地中挖到一座鐵製棺材，打開後發現鐵棺裡有一具女屍，...
#
#                                             KEYWORDS   FROM  \
# 0                                  客運,民航,美國,大陸,美陸,飛機  中時電子報
# 1                                   示威,非裔,美國,白人警員,殺害  中時電子報
# 2                   5G,華為,加拿大,美國,設備,網路建設,羅傑斯,貝爾公司,科研  中時電子報
# 3                     川普,美國,政治,民主黨,自由,經濟,城市,政策,社會,種族  中時電子報
# 4                               美國,航班,航空公司,美國政府,美東時間  中時電子報
# ..                                               ...    ...
# 195  美國暴動,川普,國民警衛隊,武器,抗議,國民警衛隊,裝甲,黑鷹,直升機,無人機,暴動,反伏擊車  中時電子報
# 196     美國,韓國,防衛費,韓籍雇員,協商,駐韓美軍,防衛費,分擔,權宜之計,2億美元,4000  中時電子報
# 197            艾倫狄珍妮,種族歧視,艾倫秀,黑人,平等,弗洛伊德,警察,壓頸,美國,偽鈔  中時電子報
# 198             張良吉,總銷約,大陸建設,琢豐,分回,飯店,美國舊金山,住宅,總銷,認列  中時電子報
# 199        女屍,專家,鐵棺,天花,19世紀,美國,紐約,歷史,廢除,黑奴,制度,保存,木乃伊  中時電子報
#
#                                                   LINK
# 0    https://www.chinatimes.com/realtimenews/202006...
# 1    https://www.chinatimes.com/realtimenews/202006...
# 2    https://www.chinatimes.com/realtimenews/202006...
# 3    https://www.chinatimes.com/opinion/20200605000...
# 4    https://www.chinatimes.com/realtimenews/202006...
# ..                                                 ...
# 195  https://www.chinatimes.com/realtimenews/202006...
# 196  https://www.chinatimes.com/realtimenews/202006...
# 197  https://www.chinatimes.com/realtimenews/202006...
# 198  https://www.chinatimes.com/newspapers/20200603...
# 199  https://www.chinatimes.com/realtimenews/202006...
#
# [200 rows x 8 columns]

# %% [markdown]
# ### 儲存結果

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-d5df0069828e> in <module>
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google'

# %% [markdown]
# ### 保存資料
# - 資料會保存在 Google Drive 上 Colab Notebooks/WebCrawler/TW_News/News 的資料夾空間中

# %%
import os
path = '/content/drive/My Drive/Colab Notebooks/WebCrawler/TW_News/News'
# 如果不存在這個資料夾就新建這個資料夾
if not os.path.exists(path):
    os.makedirs(path)
df.to_excel(path + '/News_chinatimes.xlsx')
