# %%
EX_PC24(JSON)

# %% [markdown]
# # 拆解步驟

# %%
#用Network找到有商品資料的url
import requests
res = requests.get("https://ecshweb.pchome.com.tw/search/v3.3/all/results?q=%E6%98%86%E7%9B%88&page=1&sort=sale/dc")
res
# Out:
# <Response [200]>

# %%
res.text  #發現資料為json形式
# Out:
# '{"QTime":27,"totalRows":377,"totalPage":19,"range":{"min":"","max":""},"cateName":"","q":"\\u6606\\u76c8","subq":"","token":["\\u6606\\u76c8","\\u6606","\\u76c8"],"isMust":1,"prods":[{"Id":"DCANBV-A9007DP55","cateId":"DCAN3G","picS":"\\/items\\/DCANBVA9007DP55\\/000001_1478540005.jpg","picB":"\\/items\\/DCANBVA9007DP55\\/000001_1478540005.jpg","name":"Genius \\u6606\\u76c8 NX-7000 \\u85cd\\u5149\\u7121\\u7dda\\u6ed1\\u9f20","describe":"Genius \\u6606\\u76c8 NX-7000 \\u85cd\\u5149\\u7121\\u7dda\\u6ed1\\u9f20\\\\r\\\\n\\u25cf\\u85cd\\u5149\\u6280\\u8853\\u9069\\u7528\\u4efb\\u4f55\\u6750\\u8cea\\u8868\\u9762\\uff0c\\u5982\\u9727\\u9762\\u73bb\\u7483\\u3001\\u5927\\u7406\\u77f3\\u3001\\u5730\\u6bef\\r\\n\\u25cf2.4ghz\\u7121\\u7dda\\u85cd\\u5149\\uff0c10\\u516c\\u5c3a\\u9577\\u8ddd\\u96e2\\u64cd\\u4f5c\\r\\n\\u25cf1200dpi\\u9ad8\\u89e3\\u6790\\u611f\\u61c9\\uff0c\\u7a69\\u5b9a\\u7cbe\\u6e96\\u64cd\\u63a7\\r\\n\\u25cf\\u901a\\u7528\\u7684\\u7121\\u7dda\\u63a5\\u6536\\u5668\\uff0c\\u76f8\
# ...

# %%
js = res.json()   #直接轉成json就好(不用用美湯)
js
# Out:
# {'QTime': 27,
#  'totalRows': 377,
#  'totalPage': 19,
#  'range': {'min': '', 'max': ''},
#  'cateName': '',
#  'q': '昆盈',
#  'subq': '',
#  'token': ['昆盈', '昆', '盈'],
#  'isMust': 1,
#  'prods': [{'Id': 'DCANBV-A9007DP55',
#    'cateId': 'DCAN3G',
#    'picS': '/items/DCANBVA9007DP55/000001_1478540005.jpg',
#    'picB': '/items/DCANBVA9007DP55/000001_1478540005.jpg',
#    'name': 'Genius 昆盈 NX-7000 藍光無線滑鼠',
#    'describe': 'Genius 昆盈 NX-7000 藍光無線滑鼠\\r\\n●藍光技術適用任何材質表面，如霧面玻璃、大理石、地毯\r\n●2.4ghz無線藍光，10公尺長距離操作\r\n●1200dpi高解析感應，穩定精準操控\r\n●通用的無線接收器，相容多個裝置\r\n●左右手皆適用，使用順暢\r\n●個性繽紛五色\r\n●原廠提供1年保固',
#    'price': 249,
#    'originPrice': 249,
#    'author': '',
#    'brand': '',
#    'publishDate': '',
#    'sellerId': '',
#    'isPChome': 1,
#    'isNC17': 0,
#    'couponActid': [],
#    'BU': 'ec'},
#   {'Id': 'DCANBW-A9006XV1F',
#    'cateId': 'DCAN2Q',
#    'picS': '/items/DCANBWA9006XV1F/000001_1478511485.jpg',
#    'picB': '/items/DCANBWA9006XV1F/000001_1478511485.jpg',
# ...

# %%
import pandas
df = pandas.DataFrame(js['prods'])
df1 = df[['name', 'describe', 'price', 'originPrice']]
df1
# Out:
#                                            name  \
# 0                      Genius 昆盈 NX-7000 藍光無線滑鼠
# 1                   Genius 昆盈 GAMING光學滑鼠 X-G200
# 2    Genius 昆盈 第二代 彩色精靈輕巧藍牙喇叭-消光黑(SP-906BT2-BK)
# 3    Genius 昆盈 第二代 彩色精靈輕巧藍牙喇叭-魔力紅(SP-906BT2-RD)
# 4   Genius 昆盈 彩色金屬質感藍牙喇叭-湖水綠 (SP-906BT Plus-GN)
# 5   Genius 昆盈 彩色金屬質感藍牙喇叭-葡萄紫 (SP-906BT Plus-PE)
# 6        德國百靈Oral-B-Genius10000 3D智慧追蹤電動牙刷(金鑽黑)
# 7         德國百靈Oral-B-Genius9000 3D智慧追蹤電動牙刷(玫瑰金)
# 8            德國百靈Oral-B-GeniusX 智慧追蹤3D電動牙刷(煙燻黑)
# 9        德國百靈Oral-B-Genius10000 3D智慧追蹤電動牙刷(紫鳶尾)
# 10                   Wonder Core Genius 「終極鍛鍊組」
# 11            Genius EasyPen M406 多媒體手寫繪圖板(6*4)
# 12        Genius Kids Designer 可愛塗鴉手寫繪圖板(小朋友專用)
# 13          Genius GHP-04DJ 音樂享樂Hi-Fi設計專業頂級DJ耳機
# 14       Genius HS‐G450  7.1 聲道電競耳機麥克風(磅礡的震撼音效)
# 15              Genius GHP-200X 輕量型密閉內耳式耳機-陽光橘-
# 16             Genius GHP-200X 輕量型密閉內耳式耳機-奇異果綠-
# 17               Genius MousePen M508 設計師款專業繪圖板
# ...

# %%
df2 = df1.sort_values('price', ascending=False)
df2
# Out:
#                                           name  \
# 15     EnGenius EMR3000 Mesh Wifi 覆蓋器三入組【臺灣製造】
# 16          德國百靈Oral-B-GeniusX 智慧追蹤3D電動牙刷(櫻花粉)
# 14          德國百靈Oral-B-GeniusX 智慧追蹤3D電動牙刷(煙燻黑)
# 13        德國百靈Oral-B-GeniusX AI智慧追蹤3D電動牙刷(煙燻黑)
# 9    德國百靈Oral-B-Genius9000 3D智慧追蹤電動牙刷(櫻花粉限量禮盒)
# 12      德國百靈Oral-B-Genius10000 3D智慧追蹤電動牙刷(紫鳶尾)
# 11      德國百靈Oral-B-Genius10000 3D智慧追蹤電動牙刷(金鑽黑)
# 10       德國百靈Oral-B-Genius9000 3D智慧追蹤電動牙刷(玫瑰金)
# 17                    Wonder Core Genius 健身工具箱
# 19                  Wonder Core Genius 「終極鍛鍊組」
# 18                                   培樂多新天才小牙醫
# 7   Genius 昆盈 第二代 彩色精靈輕巧藍牙喇叭-湛粉藍(SP-906BT2-BL)
# 6   Genius 昆盈 第二代 彩色精靈輕巧藍牙喇叭-魔力紅(SP-906BT2-RD)
# 5   Genius 昆盈 第二代 彩色精靈輕巧藍牙喇叭-消光黑(SP-906BT2-BK)
# 3   Genius 昆盈 NX-7015 藍光無線滑鼠-可可棕 (NX-7015-CHO)
# 4                     Genius 昆盈 NX-7000 藍光無線滑鼠
# 0       Genius昆盈Scorpion K5闇夜天王蠍電競鍵盤-黑 (K5-BK)
# 8    Genius 昆盈 NX-7010 藍光無線滑鼠-春天綠 (NX-7010-GN)
# 2    Genius 昆盈 NX-7015 藍光無線滑鼠-閃耀銀 (NX-7015-SR)
# ...

# %%
#抓取更多頁
import requests
products = []
for i in range(1,5):
    res = requests.get(f'https://ecshweb.pchome.com.tw/search/v3.3/all/results?q=%E6%98%86%E7%9B%88&page={i}&sort=sale/dc')
    js = res.json()
    df = pandas.DataFrame(js['prods'])
    df1 = df[['name', 'describe', 'price', 'originPrice']]
    products.append(df1)
df1
# Out:
#                                                name  \
# 0   Little Dinos Dont Push（Hello Genius）小恐龍不推人（外文書）
# 1       Playdate for Panda（Hello Genius）貓熊的好朋友（外文書）
# 2          【SIDI】GENIUS 7 MEGA 寬版 碳纖尼龍混合底 公路騎行車鞋 卡鞋
# 3            德國百靈Oral-B-Genius10000 3D智慧追蹤電動牙刷(金鑽黑)
# 4                          Wonder Core Genius 健身工具箱
# 5                       【Ks Kids 奇智奇思】天才釣魚組 SB00426
# 6                                     《C&B》天才家安全成長椅
# 7           GX Gaming Mordax HS-G600 震天青尾蠍震撼電競耳機麥克風
# 8                                     《C&B》天才家安全成長椅
# 9                                玩具反斗城   培樂多 新天才小牙醫
# 10        GX Gaming SOFT GAMING MOUSE PAD 極速遊戲電競滑鼠墊
# 11                                          天才認字王套書
# 12               GX Gaming Zabius M HS-G250 電競耳機麥克風
# 13              GX Gaming Maurus X 霸王黃金蠍 FPS 專業遊戲滑鼠
# 14       【荷蘭New Classic Toys】天才小木匠工具箱玩具12件組 - 18281
# 15                                     科學馬克杯系列/我是天才
# 16                                 互動電子玩具狗 手環遙控天才狗狗
# ...

# %%
products
# Out:
# [                                           name  \
#  0        德國百靈Oral-B-Genius10000 3D智慧追蹤電動牙刷(金鑽黑)
#  1         德國百靈Oral-B-Genius9000 3D智慧追蹤電動牙刷(玫瑰金)
#  2            德國百靈Oral-B-GeniusX 智慧追蹤3D電動牙刷(煙燻黑)
#  3                      Genius 昆盈 NX-7000 藍光無線滑鼠
#  4                   Genius 昆盈 GAMING光學滑鼠 X-G200
#  5    Genius 昆盈 第二代 彩色精靈輕巧藍牙喇叭-魔力紅(SP-906BT2-RD)
#  6        德國百靈Oral-B-Genius10000 3D智慧追蹤電動牙刷(紫鳶尾)
#  7    Genius 昆盈 第二代 彩色精靈輕巧藍牙喇叭-消光黑(SP-906BT2-BK)
#  8   Genius 昆盈 彩色金屬質感藍牙喇叭-湖水綠 (SP-906BT Plus-GN)
#  9   Genius 昆盈 彩色金屬質感藍牙喇叭-葡萄紫 (SP-906BT Plus-PE)
#  10                     Wonder Core Genius 健身工具箱
#  11            Genius EasyPen M406 多媒體手寫繪圖板(6*4)
#  12             Genius MousePen i608 樂活創意高階繪圖數位板
#  13        Genius Kids Designer 可愛塗鴉手寫繪圖板(小朋友專用)
#  14                   Wonder Core Genius 「終極鍛鍊組」
#  15               Genius MousePen M508 設計師款專業繪圖板
#  16               賽先生科學工廠｜懷舊鐵皮告示牌-GENIUS AT WORK
#  17       Genius GHP-02S 耳塞式隨身耳機-蛋黃色 (身臨其境的聆聽體驗)
# ...

# %%
df = pd.DataFrame(products)
df
# Out:
#                                                    0
# 0                                             nam...
# 1                                             nam...
# 2                                                ...

# %%
#將每頁合併起來
df_all = pandas.concat(products)
df_all
# Out:
#                                                  name  \
# 0              Genius昆盈Scorpion K5闇夜天王蠍電競鍵盤-黑 (K5-BK)
# 1                         Genius 昆盈 GAMING光學滑鼠 X-G200
# 2           Genius 昆盈 NX-7015 藍光無線滑鼠-閃耀銀 (NX-7015-SR)
# 3          Genius 昆盈 NX-7015 藍光無線滑鼠-可可棕 (NX-7015-CHO)
# 4                            Genius 昆盈 NX-7000 藍光無線滑鼠
# ..                                                ...
# 15  Little Monkey Calms Down（Hello Genius）小猴子不生氣（外文書）
# 16                                   NHK文藝復興藝術三傑 3DVD
# 17            GX Gaming Mordax HS-G600 震天青尾蠍震撼電競耳機麥克風
# 18    Little Dinos Dont Yell（Hello Genius）小恐龍不尖叫（外文書）
# 19        Playdate for Panda（Hello Genius）貓熊的好朋友（外文書）
#
#                                              describe  price  originPrice
# 0   Genius昆盈Scorpion K5闇夜天王蠍電競鍵盤-黑 (K5-BK)\r\n●防鬼設...    299          299
# 1   Genius 昆盈 GAMING光學滑鼠 X-G200\r\n●精準靈敏度，絕佳操控性\r\...    149          149
# 2   Genius 昆盈 NX-7015 藍光無線滑鼠-閃耀銀 (NX-7015-SR)\r\n●...    274          274
# ...

# %%
len(df_all)
# Out:
# 100

# %% [markdown]
# # PC24(JSON)_20200630完整Code

# %%
import pandas as pd
import requests
import json
import csv

#搜尋網址&換頁
def get_urls(url, query, start_page, end_page): 
    urls = []
    
    for page in range(start_page, end_page+1):
        urls.append(url.format(query, page))    #query帶入url的{0}、page帶入{1}
    print(urls)    
    return urls

def get_goods(raw_data):  

    products = raw_data['prods']
    
    df=pd.DataFrame(products).fillna('null')
    ls=df.values.tolist()
    ls.insert(0,df.columns.tolist())
    
    return ls

def save_to_csv(items, file):
    with open(file, "w+", newline="", encoding="utf_8_sig") as fp:  #utf_8_sig:能讓輸出的csv正確顯示中文(utf_8會有亂碼)
        writer = csv.writer(fp)
        for item in items:
            writer.writerow(item)

if __name__ == "__main__":
    url = "https://ecshweb.pchome.com.tw/search/v3.3/all/results?q={0}&page={1}&sort=sale/dc"
    urls = get_urls(url, "logitech", 0, 3)
    
    goods = [get_goods(requests.get(urls[0]).json())[0]]  #取第0欄(欄位名稱)
    for url in urls:
        res = requests.get(url)
        js = res.json()
        g = get_goods(js)[1:]   #取第1欄之後的資料
        goods.extend(g)  #這裡要用extend(而非append):向列表尾部追加一個列表
    
    save_to_csv(goods, "pc.csv")
# Out:
# ['https://ecshweb.pchome.com.tw/search/v3.3/all/results?q=logitech&page=0&sort=sale/dc', 'https://ecshweb.pchome.com.tw/search/v3.3/all/results?q=logitech&page=1&sort=sale/dc', 'https://ecshweb.pchome.com.tw/search/v3.3/all/results?q=logitech&page=2&sort=sale/dc', 'https://ecshweb.pchome.com.tw/search/v3.3/all/results?q=logitech&page=3&sort=sale/dc']

# %%
get_goods(requests.get(urls[0]).json())[0]
# Out:
# ['Id',
#  'cateId',
#  'picS',
#  'picB',
#  'name',
#  'describe',
#  'price',
#  'originPrice',
#  'author',
#  'brand',
#  'publishDate',
#  'sellerId',
#  'isPChome',
#  'isNC17',
#  'couponActid',
#  'BU']

# %% [markdown]
# # Pchome 爬蟲要點(完整商品資料)
# 1. 工作階段要分清楚，request、parse不要混在一起做
# 2. 先用 list 的方式存資料，最後再一起整理成 Dataframe
# 3. 加入Cookie：如果沒有放Cookie的話每次 request 資料會需要 sleep 5 秒，不然就會被鎖IP。
# 4. PChome有提供API, 所以就不用爬網頁了
# 5. 直接轉成json就好(不用用到BeautifulSoup)
# 6. 要抓完整商品資料的話，因為Pchome將產品資料放在兩個不同API，因此我們在爬蟲時需要送產品ID到這兩個API上
# 7. 合併兩個資料表，因為兩個資料不同，要先整理成相同在合併

# %% [markdown]
# # 網頁範例
# https://tlyu0419.github.io/2020/06/13/Crawler-PChome/#more

# %% [markdown]
# #### API&JSON知識
# https://tw.alphacamp.co/blog/api-introduction-understand-web-api-http-json

# %%
import requests
import json
import pandas as pd
import re
from time import sleep
from datetime import datetime

#設定 request 參數
headers = {'cookie': 'ECC=GoogleBot',  #透過塞Cookie取代sleep5秒 /而Cookie中的GoogleBot是我隨意寫的，實際上可以自己填資料。
           'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36'}

query = '筆電'
# 每次加載分頁有20筆資料
pages = 3

# 取得產品ID清單，為了後面將產品ID加到兩個API上取得資料。
prodids = []
for page in list(range(1, pages)):
    url = 'https://ecshweb.pchome.com.tw/search/v3.3/all/results?q={}&page={}&sort=sale/dc'.format(query, page)
    resp = requests.get(url,headers=headers)
    for prodid in resp.json()['prods']:  #用json直接取出prods產品列，
        prodids.append(prodid['Id'])   #在從中一個一個取出Id項目放入prodids = []
    prodids = list(set(prodids))
    print('There are {} products in list.'.format(len(prodids)))
# Out:
# There are 20 products in list.
# There are 40 products in list.

# %%
prodids
# Out:
# ['DHAFKG-A900AMCE8',
#  'DHAFKI-A900AMCDZ',
#  'DHAX97-A900AQ22D',
#  'DHAFK9-A900ANHH4',
#  'DHAFI3-A900ABRBH',
#  'DHAFHQ-A900AMA95',
#  'DHAX95-A900AO7C8',
#  'DHAX97-A900AQ21N',
#  'DHAS1U-A900AMWRG',
#  'DHAX94-A900AOR9R',
#  'DHAFKD-A900ALDOL',
#  'DHAFGB-A900A6R5O',
#  'DHAEBP-A900ADFZQ',
#  'DHAFHW-A9009GJZ1',
#  'DHAEBP-A900ADDYN',
#  'DHAFGA-A900ALT5X',
#  'DHAFJA-A900AIWC4',
#  'DHAX8W-A900AFW3E',
#  'DHAS1U-A900AQ1MJ',
#  'DHAFFM-A900ANX0I',
#  'DHAFIR-A900AEYQR',
#  'DHAFHQ-A900APJJ2',
#  'DHAFCU-A9009VYVA',
#  'DHACAC-A900ANE9G',
#  'DHAFHX-A900A4NG1',
#  'DHAFJ8-A900ABR5Q',
#  'DHAFJA-A900AIWC3',
#  'DHAFGA-A900ANW0P',
#  'DHAX97-A900AP3QA',
#  'DHAX92-A900ACQYO',
#  'DHACAF-A900A9S8Q',
#  'DHAS4K-A900APTLO',
#  'DHAFIY-A900AHFR5',
#  'DHBF5E-A900AOJMC',
#  'DHAX8W-A900AO7SG',
#  'DHAFGA-A900AKVR4',
#  'DHACAC-A900ABNY1',
#  'DHACAC-A900ABNXW',
#  'DHAFIZ-A900ALT2E',
#  'DHAEBP-A900ANKZJ']

# %%
爬取產品資料
Pchome 將產品資料放在兩個不同 API，因此我們在爬蟲時需要送產品ID 到這兩個 API上才能取到完整的資料。
這裡建議先把所有商品在一個API上的資料都抓完後再去取第二個 API 的資料，
因為兩個 API response的資料結構不一樣，我們在 parse 時會很容易搞混。

# %%
# ecapi
df1 = []
for i, Id in enumerate(prodids):
    columns, values = [], []
    print('Dealing with {}: {}'.format(i, Id))
    sleep(0.7)
    ecapi = 'https://mall.pchome.com.tw/ecapi/ecshop/prodapi/v2/prod/{}&fields=Seq,Id,Stmt,Slogan,Name,Nick,Store,PreOrdDate,SpeOrdDate,Price,Discount,Pic,Weight,ISBN,Qty,Bonus,isBig,isSpec,isCombine,isDiy,isRecyclable,isCarrier,isMedical,isBigCart,isSnapUp,isDescAndIntroSync,isFoodContents,isHuge,isEnergySubsidy,isPrimeOnly,isWarranty,isLegalStore,isOnSale,isPriceTask,isBidding,isETicket&_callback=jsonp_prod&1587196620'.format(Id)
    resp = requests.get(ecapi, headers=headers)
    #參照下方"正則解釋"
    data = re.sub('try{jsonp_prod\(|\}\);\}catch\(e\)\{if\(window.console\)\{console.log\(e\)\;\}','',resp.text)
    data = json.loads(data)[Id+'-000'] #取出API中的資料，但是此API的Id後面有多'-000'，故先加入，後面合併時再去掉

    for key, value in data.items():
        columns.append(key)
        values.append(value)
    ndf = pd.DataFrame(data=values, index=columns).T
    df1.append(ndf)
df1 = pd.concat(df1, ignore_index=True)

# cdn
df2 = []
for i, Id in enumerate(prodids):
    columns, values = [], []
    print('Dealing with {}: {}'.format(i, Id))
    sleep(0.7)
    cdn = 'https://ecapi.pchome.com.tw/cdn/ecshop/prodapi/v2/prod/{}/desc&fields=Id,Stmt,Equip,Remark,Liability,Kword,Slogan,Author,Transman,Pubunit,Pubdate,Approve&_callback=jsonp_desc'.format(Id+'-000')
    resp = requests.get(cdn, headers=headers)
    data = re.sub('try\{jsonp_desc\(|\}\);\}catch\(e\)\{if\(window.console\)\{console.log\(e\)\;\}','',resp.text)
    data = json.loads(data)
    data = data[Id]

    for key, value in data.items():
        columns.append(key)
        values.append(value)
    ndf = pd.DataFrame(data=values, index=columns).T
    df2.append(ndf)

df2 = pd.concat(df2, ignore_index=True)
# Out:
# Dealing with 0: DHBF5E-A900AOJMC
# Dealing with 1: DHAFIY-A900AHFR5
# Dealing with 2: DHAFHW-A9009GJZ1
# Dealing with 3: DHAFHQ-A900APJJ2
# Dealing with 4: DHAS4K-A900APTLO
# Dealing with 5: DHAFJA-A900AIWC3
# Dealing with 6: DHAFGB-A900A6R5O
# Dealing with 7: DHAFJ8-A900ABR5Q
# Dealing with 8: DHAEBP-A900ADDYN
# Dealing with 9: DHACAF-A900A9S8Q
# Dealing with 10: DHAFK9-A900ANHH4
# Dealing with 11: DHAFJA-A900AIWC4
# Dealing with 12: DHAFFM-A900ANX0I
# Dealing with 13: DHAFHQ-A900AMA95
# Dealing with 14: DHAEBP-A900ADFZQ
# Dealing with 15: DHAX8W-A900AFW3E
# Dealing with 16: DHAS1U-A900AQ1MJ
# Dealing with 17: DHAFKI-A900AMCDZ
# Dealing with 18: DHAX92-A900ACQYO
# Dealing with 19: DHAX97-A900AQ21N
# Dealing with 20: DHACAC-A900ABNY1
# Dealing with 21: DHAFGA-A900AKVR4
# Dealing with 22: DHAFCU-A9009VYVA
# Dealing with 23: DHAFI3-A900ABRBH
# Dealing with 24: DHAX94-A900AOR9R
# Dealing with 25: DHAEBP-A900ANKZJ
# Dealing with 26: DHACAC-A900ABNXW
# Dealing with 27: DHAX95-A900AO7C8
# ...

# %% [markdown]
# ### 正則解釋
# 這邊的正則看起來很複雜，但只是純粹把API前後多餘的文字取代掉而已，因為不像前一個API可以直接取json()['prods']<br>
# https://ecshweb.pchome.com.tw/search/v3.3/all/results?q=DHAFKG-A900AMCE8&page={}&sort=sale/dc
#
# 可以將隨便個ID代入API查看網頁格式，然後再將上面的正則和API內容貼到regex101.com就可以知道
# * df1:  https://mall.pchome.com.tw/ecapi/ecshop/prodapi/v2/prod/DHAFKG-A900AMCE8&fields=Seq,Id,Stmt,Slogan,Name,Nick,Store,PreOrdDate,SpeOrdDate,Price,Discount,Pic,Weight,ISBN,Qty,Bonus,isBig,isSpec,isCombine,isDiy,isRecyclable,isCarrier,isMedical,isBigCart,isSnapUp,isDescAndIntroSync,isFoodContents,isHuge,isEnergySubsidy,isPrimeOnly,isWarranty,isLegalStore,isOnSale,isPriceTask,isBidding,isETicket&_callback=jsonp_prod&1587196620
# * df2:  https://ecapi.pchome.com.tw/cdn/ecshop/prodapi/v2/prod/DHAFKG-A900AMCE8/desc&fields=Id,Stmt,Equip,Remark,Liability,Kword,Slogan,Author,Transman,Pubunit,Pubdate,Approve&_callback=jsonp_desc

# %%
df1
# Out:
#          Seq                    Id  \
# 0   24829575  DHBF5E-A900AOJMC-000
# 1   24236021  DHAFIY-A900AHFR5-000
# 2   21195541  DHAFHW-A9009GJZ1-000
# 3   24909394  DHAFHQ-A900APJJ2-000
# 4   24932826  DHAS4K-A900APTLO-000
# 5   24355403  DHAFJA-A900AIWC3-000
# 6   23322237  DHAFGB-A900A6R5O-000
# 7   23747765  DHAFJ8-A900ABR5Q-000
# 8   23878968  DHAEBP-A900ADDYN-000
# 9   23573595  DHACAF-A900A9S8Q-000
# 10  24739711  DHAFK9-A900ANHH4-000
# 11  24355404  DHAFJA-A900AIWC4-000
# 12  24776277  DHAFFM-A900ANX0I-000
# 13  24640418  DHAFHQ-A900AMA95-000
# 14  23883595  DHAEBP-A900ADFZQ-000
# 15  24098306  DHAX8W-A900AFW3E-000
# 16  24950510  DHAS1U-A900AQ1MJ-000
# 17  24644545  DHAFKI-A900AMCDZ-000
# 18  23827032  DHAX92-A900ACQYO-000
# 19  24951374  DHAX97-A900AQ21N-000
# 20  23740655  DHACAC-A900ABNY1-000
# 21  24519177  DHAFGA-A900AKVR4-000
# 22  22286510  DHAFCU-A9009VYVA-000
# 23  23748299  DHAFI3-A900ABRBH-000
# 24  24846522  DHAX94-A900AOR9R-000
# ...

# %%
df2
# Out:
#                   Id                                               Stmt  \
# 0   DHBF5E-A900AOJMC  <a name="規格說明">Lenovo IdeaPad Slim 5i 81YK006V...
# 1   DHAFIY-A900AHFR5  <a name="規格說明"> ASUS VivoBook X412FL-0231G1021...
# 2   DHAFHW-A9009GJZ1  <a name="規格說明">ASUS TP202NA-0101KN3350 星空灰 詳細規...
# 3   DHAFHQ-A900APJJ2  <a name="規格說明"> ASUS X571LH-0111K10750H 星夜黑 詳細...
# 4   DHAS4K-A900APTLO  <a name="規格說明">ASUS ROG SCAR G732LWS-0031A1087...
# 5   DHAFJA-A900AIWC3  <a name="規格說明"> ASUS VivoBook S14 S432FL-0062S...
# 6   DHAFGB-A900A6R5O  <a name="規格說明"> ASUS VivoBook S15 S531FL-0122B...
# 7   DHAFJ8-A900ABR5Q  <a name="規格說明"> ASUS ZenBook 15 UX534FTC-0102B...
# 8   DHAEBP-A900ADDYN  <a name="規格說明"> Acer SF314-57-787W 灰 詳細規格表</a>...
# 9   DHACAF-A900A9S8Q  Laptop Requirements\r\n(Laptop not included)\r...
# 10  DHAFK9-A900ANHH4  <a name="規格說明">ASUS X509JP-0171G1065G7 星空灰  詳細...
# 11  DHAFJA-A900AIWC4  <a name="規格說明"> ASUS VivoBook S14 S432FL-0082E...
# ...

# %% [markdown]
# ### 合併兩個資料表
# 這裡就是我說資料結構不一致的地方<br>
# 第一個 API 取回來的 產品ID 最後會包含’-000’的字串，而第二個 API 取回來的則是乾淨的產品ID，<br>
# 要將兩個資料表透過產品ID合併在一起時要先將’-000’的字串拿掉，具體的語法如下：

# %%
df1['Id'] = df1['Id'].apply(lambda x: re.sub('-000$','',x))
df = pd.merge(df1, df2, how='left',on='Id')

# %%
爬取結果
這次我們總共取回 978個產品，與 45 個產品特徵，一下簡單挑選重要的特徵來說明

Id： 產品ID，在產品ID前面加上’https://24h.pchome.com.tw/prod/’，即是產品在Pchome上的網址
範例：https://24h.pchome.com.tw/prod/DHAFHQ-A900AMA95

Name：產品名稱
Price：產品價格，欄位中包含原價和特價兩種價格，在使用時需要再從中解析資料。
Stmt：產品描述
Equip：配備
Remark：備註
Liability：保固資訊
Kword：關鍵字
Slogan：標語
…

# %%
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40 entries, 0 to 39
# Data columns (total 45 columns):
# Seq                   40 non-null object
# Id                    40 non-null object
# Name                  40 non-null object
# Nick                  40 non-null object
# Store                 40 non-null object
# PreOrdDate            40 non-null object
# SpeOrdDate            40 non-null object
# Price                 40 non-null object
# Discount              40 non-null object
# Pic                   40 non-null object
# Weight                40 non-null object
# ISBN                  40 non-null object
# Qty                   40 non-null object
# Bonus                 40 non-null object
# isBig                 40 non-null object
# isSpec                40 non-null object
# isCombine             40 non-null object
# isDiy                 40 non-null object
# isRecyclable          40 non-null object
# isCarrier             40 non-null object
# ...

# %%
df.to_excel('./Pchome_NB.xlsx')
